# %% [markdown]
# # Convenience notebook for dropping and repopulating database

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Delete DB

# %%
run -im djd.main -- --dbname=dj_lisa --user=write
# Out:
# Connecting write@huxley.neuro.bzm:3306
# Connected to database 'dj_lisa' as 'write@10.153.173.165'

# %%
from djd.glms import plot_model

# %%
key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 20, 'spl_paramset': 601}
fig, ax = plot_model(key, title=True)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 20, 'spl_paramset': 602}
fig, ax = plot_model(key, title=True)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 20, 'spl_paramset': 603}
fig, ax = plot_model(key, title=True)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 20, 'spl_paramset': 604}
fig, ax = plot_model(key, title=True)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 20, 'spl_paramset': 605}
fig, ax = plot_model(key, title=True)

# %%
key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 9, 'u': 18, 'spl_paramset': 1, 'spl_stim': 'spnoise'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 9, 'u': 18, 'spl_paramset': 2, 'spl_stim': 'spnoise'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 9, 'u': 18, 'spl_paramset': 3, 'spl_stim': 'spnoise'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 9, 'u': 18, 'spl_paramset': 4, 'spl_stim': 'spnoise'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 9, 'u': 18, 'spl_paramset': 5, 'spl_stim': 'spnoise'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 18, 'spl_paramset': 601, 'spl_stim': 'hmov'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 18, 'spl_paramset': 602, 'spl_stim': 'hmov'}
fig, ax = plot_model(key)

key = {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 18, 'spl_paramset': 603, 'spl_stim': 'hmov'}
fig, ax = plot_model(key)

# %%
Mouse()
# Out:
# *m               m_strain      m_genotype     m_dob          m_sex     m_craniox     m_cranioy     m_refx      m_refy     m_notes          m_protocol       m_ts
# +--------------+ +-----------+ +------------+ +------------+ +-------+ +-----------+ +-----------+ +---------+ +--------+ +--------------+ +--------------+ +--------------+
# Ntsr1Cre_2019_00 Ntsr1-Cre     +/-            2019-04-05     M         -2.3          -2.3          midline     bregma     Inject stGtACR2  ROB-55.2Vet-2532 2021-08-20 16:07
# Ntsr1Cre_2019_00 Ntsr1-Cre     +/-            2019-09-25     M         -2.3          -2.3          midline     bregma     Inject stGtACR2  ROB-55.2Vet-2532 2021-08-20 16:10
# Ntsr1Cre_2020_00 Ntsr1-Cre     -/-            2019-10-17     M         -3.28         -2.35         midline     bregma     purpose: CONTROL ROB-55.2-2532.Ve 2021-08-20 16:12
# Ntsr1Cre_2020_00 Ntsr1-Cre     +/-            2020-03-29     M         -3.28         -2.3          midline     bregma     purpose: silenci ROB-55.2-2532.Ve 2021-08-20 16:14
#  (Total: 4)

# %%
# HmovUnit().drop()
# Out:
# `dj_hmov`.`__hmov_unit` (159 tuples)
# Proceed? [yes, No]:  yes
# Tables dropped.  Restart kernel.

# %%
# Drop all tables - restart kernel and continue from next cell on 2nd run
# dropall()
# Out:
# Dropping all tables in 'dj_hmov' database
# Proceed to delete entire schema `dj_hmov`? [yes, No]:  yes
# Please restart your Python session if you confirmed with `yes`

# %% [markdown]
# ## Restart DB and set parameters to populate

# %%
run -im djd.main -- --dbname=dj_hmov --user=execute
# Out:
# Enter MySQL password for 'execute':  ··············
# Connecting execute@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'execute@10.153.173.165'

# %%
Mouse()
# Out:
# *m    m_strain     m_genotype     m_dob     m_sex     m_craniox     m_cranioy     m_refx     m_refy     m_notes     m_protocol     m_ts
# +---+ +----------+ +------------+ +-------+ +-------+ +-----------+ +-----------+ +--------+ +--------+ +---------+ +------------+ +------+
#
#  (Total: 0)

# %% [markdown]
# ## Define paramsets

# %% [markdown]
# ### dj_hmov pars

# %%
# Define SplineLNPParams() parameter to populate

# spnoise: paramest given by Lisa
slnp_pars1 = {
    'spl_paramset': 1,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: testing
slnp_pars2 = {
    'spl_paramset': 2,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.0,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: testing
slnp_pars3 = {
    'spl_paramset': 3,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 16,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: testing
slnp_pars4 = {
    'spl_paramset': 4,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.025,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: testing 
slnp_pars5 = {
    'spl_paramset': 5,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.025,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: testing higher temp_df
slnp_pars6 = {
    'spl_paramset': 6,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: spnoise paramset 1 - now using new get_rf_area() results
slnp_pars7 = {
    'spl_paramset': 7,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# Best paramset from Lisa's recent sets without all extra filters
slnp_pars407 = {
    'spl_paramset': 407,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 6,
    'spl_temp_df': 7,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing spat_df w still low lr and high iterations
slnp_pars600 = {
    'spl_paramset': 600,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 10,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing spat_df=12 whigher lr and fewer iterations
slnp_pars601 = {
    'spl_paramset': 601,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 12,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing spat_df=16
slnp_pars602 = {
    'spl_paramset': 602,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 16,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing 12x12 df
slnp_pars603 = {
    'spl_paramset': 603,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.0,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 12,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing high spatial scaling 0.12
slnp_pars604 = {
    'spl_paramset': 604,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 12,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.12,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing high spat_df and high spatial scaling 0.12 paramset
slnp_pars605 = {
    'spl_paramset': 605,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 16,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.12,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing hmov paramset that matches spnoise paramset 1 ito stim resolution and splines per deg
slnp_pars606 = {
    'spl_paramset': 606,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 13,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0495,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing new get_rf_area() results against paramset 601 with same parameters
slnp_pars607 = {
    'spl_paramset': 607,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.2,
    'spl_max_iter': 1000,
    'spl_spat_df': 12,
    'spl_temp_df': 12,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.06,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing hmov paramset that matches spnoise paramset 1 ito stim resolution and splines per deg - now using new get_rf_area() results
slnp_pars608 = {
    'spl_paramset': 608,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 13,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0495,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# Testing high-res hmov paramset to compare w hmov paramset that matches spnoise paramset 1 ito stim resolution and splines per deg - checking RF new area
slnp_pars609 = {
    'spl_paramset': 609,
    'spl_stim': 'hmov',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 1.4,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 13,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 20,
    'spl_pshf_df': 10,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'False',
    'spl_nlag': 20,
    'spl_shift': 1,
    'spl_spat_scaling': 0.12,
    'spl_data_fs': 60.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'True',
}

# %% [markdown]
# ### dj_lisa pars

# %%
# Define SplineLNPParams() parameter to populate

# spnoise: paramest given by Lisa
slnp_pars1 = {
    'spl_paramset': 1,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: increasing regularization compared to 1
slnp_pars2 = {
    'spl_paramset': 2,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.1,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'True',
    'spl_pshf_len': 10,
    'spl_pshf_df': 8,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: like 1 without PSHF
slnp_pars3 = {
    'spl_paramset': 3,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.05,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'False',
    'spl_pshf_len': 0,
    'spl_pshf_df': 0,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# spnoise: like 2 (higher reg) without PSHF
slnp_pars4 = {
    'spl_paramset': 4,
    'spl_stim': 'spnoise',
    'spl_distr': 'softplus',
    'spl_alpha': 1.0,
    'spl_lambda': 0.1,
    'spl_lr': 0.1,
    'spl_max_iter': 1500,
    'spl_spat_df': 12,
    'spl_temp_df': 8,
    'spl_pshf': 'False',
    'spl_pshf_len': 0,
    'spl_pshf_df': 0,
    'spl_verb': 200,
    'spl_metric': 'corrcoef',
    'spl_norm_y': 'True',
    'spl_nlag': 10,
    'spl_shift': 1,
    'spl_spat_scaling': 0.0,
    'spl_data_fs': 50.0,
    'spl_opto': 'False',
    'spl_opto_len': 0,
    'spl_opto_df': 0,
    'spl_run': 'False',
    'spl_run_len': 0,
    'spl_run_df': 0,
    'spl_eye': 'False',
    'spl_eye_len': 0,
    'spl_eye_df': 0,
    'spl_eye_smooth': 'False',
}

# %%
# SplineLNPParams().populate(slnp_pars1)
SplineLNPParams().populate(slnp_pars407)

# %%
# (SplineLNPParams() & {'spl_paramset': 5}).delete()
# Out:
# About to delete:
# `dj_hmov`.`__spline_l_n_p__eval`: 1 items
# `dj_hmov`.`__spline_l_n_p`: 1 items
# `dj_hmov`.`spline_l_n_p_params`: 1 items
# Proceed? [yes, No]:  yes
# Committed.

# %%
SplineLNPParams()
# Out:
# *spl_paramset    *spl_stim    spl_distr     spl_alpha     spl_lambda     spl_lr     spl_max_iter     spl_spat_df     spl_temp_df     spl_pshf     spl_pshf_len     spl_pshf_df     spl_verb     spl_metric     spl_norm_y     spl_nlag     spl_shift     spl_spat_scaling spl_data_fs     spl_opto     spl_opto_len     spl_opto_df     spl_run     spl_run_len     spl_run_df     spl_eye     spl_eye_len     spl_eye_df     spl_eye_smooth
# +--------------+ +----------+ +-----------+ +-----------+ +------------+ +--------+ +--------------+ +-------------+ +-------------+ +----------+ +--------------+ +-------------+ +----------+ +------------+ +------------+ +----------+ +-----------+ +--------------+ +-------------+ +----------+ +--------------+ +-------------+ +---------+ +-------------+ +------------+ +---------+ +-------------+ +------------+ +--------------+
# 1                spnoise      softplus      1.0           0.05           0.1        1500             12              8               True         10               8               200          corrcoef       True           10           1             0.0              50.0            False        0                0               False       0               0              False       0               0              False
# 2                spnoise      softplus      1.0           0.1            0.1        1500             12              8               True         10               8               200          corrcoef       True           10           1             0.0              50.0            False        0                0               False       0               0              False       0               0              False
# 3                spnoise      softplus      1.0           0.05           0.1        1500             12              8               False        0                0               200          corrcoef       True           10           1             0.0              50.0            False        0                0               False       0               0              False       0               0              False
# 4                spnoise      softplus      1.0           0.1            0.1        1500             12              8               False        0                0               200          corrcoef       True           10           1             0.0              50.0            False        0                0               False       0               0              False       0               0              False
# 100              hmov         softplus      1.0           1.0            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        40              13             True        40              13             True
# 101              hmov         softplus      1.0           1.0            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        50              16             True        50              16             True
# 102              hmov         softplus      1.0           1.0            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        30              10             True        30              10             True
# 103              hmov         softplus      1.0           2.5            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        40              13             True        40              13             True
# 104              hmov         softplus      1.0           2.5            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        50              16             True        50              16             True
# 105              hmov         softplus      1.0           2.5            0.3        1500             13              11              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         20               11              True        30              10             True        30              10             True
# 407              hmov         softplus      1.0           1.4            0.1        1500             6               7               True         20               10              200          corrcoef       False          20           1             0.06             60.0            False        0                0               False       0               0              False       0               0              True
# 700              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              False       0               0              False
# 701              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              True        20              8              True
# 702              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              8              False       0               0              False
# 703              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              8              True        20              8              True
# 704              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               False       0               0              False       0               0              False
# 705              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               False       0               0              True        20              8              True
# 706              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               True        20              8              False       0               0              False
# 707              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               True        20              8              True        20              8              True
# 708              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              False       0               0              False
# 709              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              True        20              8              True
# 710              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              8              False       0               0              False
# 711              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              8              True        20              8              True
# 712              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               False       0               0              False       0               0              False
# 713              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               False       0               0              True        20              8              True
# 714              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               True        20              8              False       0               0              False
# 715              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               6               200          corrcoef       False          20           1             0.0495           60.0            True         15               6               True        20              8              True        20              8              True
# 716              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              False       0               0              False
# 717              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              True        20              10             True
# 718              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              10             False       0               0              False
# 719              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              10             True        20              10             True
# 720              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               False       0               0              False       0               0              False
# 721              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               False       0               0              True        20              10             True
# 722              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               True        20              10             False       0               0              False
# 723              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               True        20              10             True        20              10             True
# 724              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              False       0               0              False
# 725              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              True        20              10             True
# 726              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              10             False       0               0              False
# 727              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              10             True        20              10             True
# 728              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               False       0               0              False       0               0              False
# 729              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               False       0               0              True        20              10             True
# 730              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               True        20              10             False       0               0              False
# 731              hmov         softplus      1.0           5.0            0.1        1500             13              13              True         15               8               200          corrcoef       False          20           1             0.0495           60.0            True         15               8               True        20              10             True        20              10             True
# 732              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              False       0               0              False
# 733              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               False       0               0              True        20              12             True
# 734              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              12             False       0               0              False
# 735              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            False        0                0               True        20              12             True        20              12             True
# 736              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               10              False       0               0              False       0               0              False
# 737              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               10              False       0               0              True        20              12             True
# 738              hmov         softplus      1.0           5.0            0.1        1500             13              13              False        0                0               200          corrcoef       False          20           1             0.0495           60.0            True         15               10              True        20              12             False       0               0              False
#    ...
#  (Total: 876)

# %%
(SplineLNP() & {'m': 'Ntsr1Cre_2019_0008', 's': 5, 'u': 48, 'e': 8})#.delete()
# Out:
# *m               *s    *e    *u     *spl_paramset    *spl_stim    spl_n_basis     spl_b      spl_w_opt  spl_h      spl_h_init spl_o      spl_o_init spl_r      spl_r_init spl_e      spl_e_init spl_y_trai spl_yhat_t spl_y_val  spl_yhat_v spl_y_test spl_yhat_t spl_y_test spl_yhat_t spl_ts
# +--------------+ +---+ +---+ +----+ +--------------+ +----------+ +-------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------------+
# Ntsr1Cre_2019_00 5     8     48     601              hmov         2592            =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-06-29 13:56
#  (Total: 1)

# %%
# SplineLNP().populate({'m': 'Ntsr1Cre_2020_0004', 's': 6, 'spl_paramset': 601, 'reserve_jobs': True}) # hmov
# SplineLNP().populate({'m': 'Ntsr1Cre_2020_0004', 's': 6, 'spl_paramset': 602, 'reserve_jobs': True}) # hmov
SplineLNP().populate({'m': 'Ntsr1Cre_2020_0004', 's': 6, 'spl_paramset': 603, 'reserve_jobs': True}) # hmov
# SplineLNP().populate({'m': 'Ntsr1Cre_2020_0004', 's': 6, 'spl_paramset': 604})#, 'reserve_jobs': True}) # hmov
# Out:
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 3, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 3, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	    11.747	-160903.569	-63140.721	     0.306	     0.259
#   200	    59.942	-266661.152	-100474.655	     0.446	     0.428
#   400	   108.952	-267615.896	-100804.907	     0.464	     0.448
#   600	   158.774	-267802.637	-100860.943	     0.468	     0.452
#   800	   208.725	-267892.400	-100881.761	     0.470	     0.453
# Stop: reached 1000 steps.
#
# Total time elapsed: 258.484 s.
# SplineLNP.Eval() parentkey: {'u': 3, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 5, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 5, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     9.305	-47392.240	-20295.405	     0.139	     0.139
#   200	    57.296	-69463.126	-28306.648	     0.233	     0.246
#   400	   106.224	-69614.628	-28355.480	     0.240	     0.253
#   600	   155.981	-69699.380	-28386.831	     0.244	     0.257
#   800	   205.786	-69784.721	-28423.964	     0.250	     0.261
# Stop: reached 1000 steps.
#
# Total time elapsed: 255.228 s.
# SplineLNP.Eval() parentkey: {'u': 5, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 6, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 6, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	    12.374	-315407.977	-105617.348	     0.421	     0.439
#   200	    59.682	-535249.384	-170906.871	     0.526	     0.557
#   400	   108.140	-537675.629	-171816.180	     0.545	     0.579
#   600	   157.289	-538053.906	-171968.406	     0.549	     0.583
#   800	   206.382	-538238.963	-172040.053	     0.552	     0.586
# Stop: reached 1000 steps.
#
# Total time elapsed: 255.266 s.
# SplineLNP.Eval() parentkey: {'u': 6, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 7, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 7, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     9.366	-96273.252	-42997.243	     0.134	     0.224
#   200	    57.237	-160779.711	-66387.870	     0.380	     0.414
#   400	   106.060	-161197.455	-66507.411	     0.393	     0.427
#   600	   155.880	-161308.919	-66563.453	     0.396	     0.430
#   800	   205.620	-161363.492	-66591.203	     0.398	     0.432
# Stop: reached 1000 steps.
#
# Total time elapsed: 255.054 s.
# SplineLNP.Eval() parentkey: {'u': 7, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 9, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 9, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     9.416	-57560.771	-23708.315	    -0.039	    -0.025
#   200	    57.310	-96495.223	-36580.541	     0.204	     0.221
#   400	   106.107	-96654.905	-36644.048	     0.216	     0.231
#   600	   155.788	-96684.008	-36656.596	     0.219	     0.233
#   800	   205.451	-96708.434	-36667.744	     0.221	     0.234
# Stop: reached 1000 steps.
#
# Total time elapsed: 254
 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 68, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 68, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     8.972	-189545.759	-85586.387	     0.086	     0.149
#   200	    56.855	-325124.265	-139230.407	     0.234	     0.259
#   400	   105.677	-326362.893	-139622.202	     0.247	     0.273
#   600	   155.416	-326928.413	-139767.648	     0.253	     0.282
#   800	   205.102	-326987.117	-139764.933	     0.255	     0.284
# Stop: reached 1000 steps.
#
# Total time elapsed: 254.587 s.
# SplineLNP.Eval() parentkey: {'u': 68, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 70, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Eye() is empty for key  {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 10, 'u': 70, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     9.029	-174551.573	-57727.284	     0.087	     0.027
#   200	    56.909	-298727.076	-92306.249	     0.188	     0.113
#   400	   105.693	-300474.071	-92988.557	     0.196	     0.126
#   600	   155.426	-300889.176	-93215.197	     0.199	     0.132
#   800	   205.113	-300901.882	-93233.166	     0.199	     0.134
# Stop: reached 1000 steps.
#
# Total time elapsed: 254.588 s.
# SplineLNP.Eval() parentkey: {'u': 70, 'spl_paramset': 603, 's': 6, 'spl_stim': 'hmov', 'm': 'Ntsr1Cre_2020_0004', 'e': 10}

# %%
SplineLNP() & {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'spl_paramset': 601}
# Out:
# *m    *s    *e    *u    *spl_paramset    *spl_stim    spl_n_basis     spl_b      spl_w_opt  spl_h      spl_h_init spl_o      spl_o_init spl_r      spl_r_init spl_e      spl_e_init spl_y_trai spl_yhat_t spl_y_val  spl_yhat_v spl_y_test spl_yhat_t spl_y_test spl_yhat_t spl_ts
# +---+ +---+ +---+ +---+ +--------------+ +----------+ +-------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
#
#  (Total: 0)

# %%
# Define GlmParams() pars to populate
glm_pars = {
 'glm_paramset': 1,
 'glm_distr': 'softplus',
 'glm_alpha': 1.0,
 'glm_lambda': 0.00015,
 'glm_solver': 'batch-gradient',
 'glm_lr': 0.7,
 'glm_max_iter': 1000,
 'glm_tol': 1e-06,
 'glm_seed': 0,
 'glm_norm_y': 'True',
 'glm_nlag': 8,
 'glm_shift': 1,
 'glm_spat_scaling': 0.06}

# %%
GlmParams().populate(glm_pars)

# %%
GlmParams()
# Out:
# *glm_paramset    glm_distr     glm_alpha     glm_lambda     glm_solver       glm_lr     glm_max_iter     glm_tol     glm_seed     glm_norm_y     glm_nlag     glm_shift     glm_spat_scaling
# +--------------+ +-----------+ +-----------+ +------------+ +--------------+ +--------+ +--------------+ +---------+ +----------+ +------------+ +----------+ +-----------+ +--------------+
# 1                softplus      1.0           0.00015        batch-gradient   0.7        1000             1e-06       0            True           8            1             0.06
#  (Total: 1)

# %% [markdown]
# ## Repopulate DB

# %%
Unit.Spikes() & {'m':'Ntsr1Cre_2020_0001', 's':2, 'e':7}
# Out:
# *m               *s    *e    *u      spk_times
# +--------------+ +---+ +---+ +-----+ +--------+
# Ntsr1Cre_2020_00 2     7     2       =BLOB=
# Ntsr1Cre_2020_00 2     7     3       =BLOB=
# Ntsr1Cre_2020_00 2     7     6       =BLOB=
# Ntsr1Cre_2020_00 2     7     8       =BLOB=
# Ntsr1Cre_2020_00 2     7     19      =BLOB=
# Ntsr1Cre_2020_00 2     7     21      =BLOB=
# Ntsr1Cre_2020_00 2     7     36      =BLOB=
# Ntsr1Cre_2020_00 2     7     38      =BLOB=
# Ntsr1Cre_2020_00 2     7     44      =BLOB=
# Ntsr1Cre_2020_00 2     7     54      =BLOB=
# Ntsr1Cre_2020_00 2     7     55      =BLOB=
# Ntsr1Cre_2020_00 2     7     58      =BLOB=
# Ntsr1Cre_2020_00 2     7     59      =BLOB=
# Ntsr1Cre_2020_00 2     7     65      =BLOB=
# Ntsr1Cre_2020_00 2     7     66      =BLOB=
# Ntsr1Cre_2020_00 2     7     99      =BLOB=
# Ntsr1Cre_2020_00 2     7     150     =BLOB=
#  (Total: 17)

# %%
HmovUnit() & {'m':'Ntsr1Cre_2020_0001', 's':2, 'e':7, 'u':19}
# Out:
# *m    *s    *e    *u    hm_version     hm_seq_num     hmu_fr_mean_e    hmu_fr_var_e     hmu_fr_mean_stim hmu_fr_mean_stim hmu_fr_var_stim_ hmu_fr_mean_stim hmu_fr_var_stim_ hmu_fr_mean_spon hmu_fr_var_spont hmu_fr_mean_spon hmu_fr_var_spont hmu_omi_e     hmu_omi_stim     hmu_omi_spont    hmu_rmi_e     hmu_emi_e     hmu_oracle     hmu_explainable_ hmu_sta_co hmu_ts
# +---+ +---+ +---+ +---+ +------------+ +------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +-----------+ +--------------+ +--------------+ +-----------+ +-----------+ +------------+ +--------------+ +--------+ +--------+
#
#  (Total: 0)

# %%
SplineLNP.populate({'m':'Ntsr1Cre_2020_0001', 's':2, 'e':7, 'u':58})
# Out:
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 100, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 100, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 101, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 101, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 102, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 102, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 103, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 103, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 104, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 104, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 105, 'spl_stim': 'hmov'}
# 	EyeIxtract() is empty for key  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 105, 'spl_stim': 'hmov'}
# 	Data object loaded without eye attributes.
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7, 'u': 58, 'spl_paramset': 407, 'spl_stim': 'hmov'}
# > /Users/ybauer/code/djd/djd/glms.py(713)make()
#     711                     import pdb
#     712                     pdb.set_trace()
# --> 713                     data = get_hmov_data(parentkey,
#     714                                          scaling=pars['spat_scaling'],
#     715                                          stim_interp_kind=PARS_STIM_INTERP1D,
# ipdb>  pars['spat_scaling']
# 0.06
# ipdb>  PARS_STIM_INTERP1D
# 'nearest'
# ipdb>  PSTH_BINW
# 0.1
# ipdb>  PARS_RESP_INTERP1D
# 'nearest'
# ipdb>  pars['norm_y']
# False
# ipdb>  pars['eye_smooth']
# True
# ipdb>  pars['opto']
# False
# ipdb>  pars['eye']
# False
# ipdb>  pars['data_fs']
# 60.0
# ipdb>  data
# *** NameError: name 'data' is not defined
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(714)make()
#     712                     pdb.set_trace()
#     713                     data = get_hmov_data(parentkey,
# --> 714                                          scaling=pars['spat_scaling'],
#     715                                          stim_interp_kind=PARS_STIM_INTERP1D,
#     716                                          psth_binw=PSTH_BINW,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(715)make()
#     713                     data = get_hmov_data(parentkey,
#     714                                          scaling=pars['spat_scaling'],
# --> 715                                          stim_interp_kind=PARS_STIM_INTERP1D,
#     716                                          psth_binw=PSTH_BINW,
#     717                                          resp_interp_kind=PARS_RESP_INTERP1D,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(716)make()
#     714                                          scaling=pars['spat_scaling'],
#     715                                          stim_interp_kind=PARS_STIM_INTERP1D,
# --> 716                                          psth_binw=PSTH_BINW,
#     717                                          resp_interp_kind=PARS_RESP_INTERP1D,
#     718                                          normalize=pars['norm_y'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(717)make()
#     715                                          stim_interp_kind=PARS_STIM_INTERP1D,
#     716                                          psth_binw=PSTH_BINW,
# --> 717                                          resp_interp_kind=PARS_RESP_INTERP1D,
#     718                                          normalize=pars['norm_y'],
#     719                                          standardize=False,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(718)make()
#     716                                          psth_binw=PSTH_BINW,
#     717                                          resp_interp_kind=PARS_RESP_INTERP1D,
# --> 718                                          normalize=pars['norm_y'],
#     719                                          standardize=False,
#     720                                          rate=False,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(719)make()
#     717                                          resp_interp_kind=PARS_RESP_INTERP1D,
#     718                                          normalize=pars['norm_y'],
# --> 719                                          standardize=False,
#     720                                          rate=False,
#     721                                          opto=pars['opto'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(720)make()
#     718                                          normalize=pars['norm_y'],
#     719                                          standardize=False,
# --> 720                                          rate=False,
#     721                                          opto=pars['opto'],
#     722                                          run=pars['run'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(721)make()
#     719                                          standardize=False,
#     720                                          rate=False,
# --> 721                                          opto=pars['opto'],
#     722                                          run=pars['run'],
#     723                                          get_run_speed=True,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(722)make()
#     720                                          rate=False,
#     721                                          opto=pars['opto'],
# --> 722                                          run=pars['run'],
#     723                                          get_run_speed=True,
#     724                                          eye=pars['eye'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(723)make()
#     721                                          opto=pars['opto'],
#     722                                          run=pars['run'],
# --> 723                                          get_run_speed=True,
#     724                                          eye=pars['eye'],
#     725                                          smooth_eye=pars['eye_smooth'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(724)make()
#     722                                          run=pars['run'],
#     723                                          get_run_speed=True,
# --> 724                                          eye=pars['eye'],
#     725                                          smooth_eye=pars['eye_smooth'],
#     726                                          data_fs=pars['data_fs'],
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(725)make()
#     723                                          get_run_speed=True,
#     724                                          eye=pars['eye'],
# --> 725                                          smooth_eye=pars['eye_smooth'],
#     726                                          data_fs=pars['data_fs'],
#     727                                          split_train_val=True,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(726)make()
#     724                                          eye=pars['eye'],
#     725                                          smooth_eye=pars['eye_smooth'],
# --> 726                                          data_fs=pars['data_fs'],
#     727                                          split_train_val=True,
#     728                                          dtype=np.float16,#uint8,
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(727)make()
#     725                                          smooth_eye=pars['eye_smooth'],
#     726                                          data_fs=pars['data_fs'],
# --> 727                                          split_train_val=True,
#     728                                          dtype=np.float16,#uint8,
#     729                                          verbose=True)
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(728)make()
#     726                                          data_fs=pars['data_fs'],
#     727                                          split_train_val=True,
# --> 728                                          dtype=np.float16,#uint8,
#     729                                          verbose=True)
#     730
# ipdb>  n
# > /Users/ybauer/code/djd/djd/glms.py(729)make()
#     727                                          split_train_val=True,
#     728                                          dtype=np.float16,#uint8,
# --> 729                                          verbose=True)
#     730
#     731                     if PARS_STIM_INTERP1D == 'nearest':
# ipdb>  n
# datajoint.errors.LostConnectionError: ('Connection timed out', "MySQL server has gone away (BrokenPipeError(32, 'Broken pipe'))")
# > /Users/ybauer/code/djd/djd/glms.py(729)make()
#     727                                          split_train_val=True,
#     728                                          dtype=np.float16,#uint8,
# --> 729                                          verbose=True)
#     730
#     731                     if PARS_STIM_INTERP1D == 'nearest':
# ipdb>  q
# Ntsr1Cre_2020_0001 s02 e07 u58 skipped due to :
# ---------------------------------------------------------------------------
# LostConnectionError                       Traceback (most recent call last)
# ~/code/djd/djd/main.py in <module>
# ----> 1 SplineLNP.populate({'m':'Ntsr1Cre_2020_0001', 's':2, 'e':7, 'u':58})
#
# ~/miniconda3/lib/python3.7/site-packages/datajoint/autopopulate.py in populate(self, suppress_errors, return_exception_objects, reserve_jobs, order, limit, max_calls, display_progress, *restrictions)
#     151                     self.__class__._allow_insert = True
#     152                     try:
# --> 153                         make(dict(key))
#     154                     except (KeyboardInterrupt, SystemExit, Exception) as error:
#     155                         try:
#
# ~/miniconda3/lib/python3.7/site-packages/datajoint/connection.py in commit_transaction(self)
#     356
#     357         """
# --> 358         self.query('COMMIT')
#     359         self._in_transaction = False
#     360         logger.info("Transaction committed and closed.")
#
# ~/miniconda3/lib/python3.7/site-packages/datajoint/connection.py in query(self, query, args, as_dict, suppress_warnings, reconnect)
#     298         cursor = self._conn.cursor(cursor=cursor_class)
#     299         try:
# --> 300             self._execute_query(cursor, query, args, suppress_warnings)
#     301         except errors.LostConnectionError:
#     302             if not reconnect:
#
# ~/miniconda3/lib/python3.7/site-packages/datajoint/connection.py in _execute_query(cursor, query, args, suppress_warnings)
#     264                 cursor.execute(query, args)
#     265         except client.err.Error as err:
# --> 266             raise translate_query_error(err, query)
#     267
#     268     def query(self, query, args=(), *, as_dict=False, suppress_warnings=True, reconnect=None):
#
# LostConnectionError: Server connection lost due to an interface error.

# %%
# Define mice to populate
mouse_ids = [
    {'m': 'Ntsr1Cre_2019_0002'},
    {'m': 'Ntsr1Cre_2019_0003'},
    {'m': 'Ntsr1Cre_2019_0007'},
    {'m': 'Ntsr1Cre_2019_0008'},
    {'m': 'Ntsr1Cre_2020_0001'},
    {'m': 'Ntsr1Cre_2020_0002'},
    {'m': 'Ntsr1Cre_2020_0003'},
    {'m': 'Ntsr1Cre_2020_0004'}
    ]

# %%
# Define sparse noise msekeys
msekeys = (Series.Experiment() & {'e_name': 'AsparseNoise5_60deg'}).fetch(dj.key)
msekeys
# Out:
# [{'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 7},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 2},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 6},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 3, 'e': 1},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 4, 'e': 1},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 5, 'e': 1},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 1},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 3, 'e': 3},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 4, 'e': 3},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 5, 'e': 3},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 6, 'e': 3},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 7, 'e': 3},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 8, 'e': 3},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 1, 'e': 2},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 3, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 3, 'e': 13},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 4, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 1, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 2, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 3, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 4, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 5, 'e': 1},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 6, 'e': 1}]

# %%
Series.Experiment()
# Out:
# *m               *s    *e     e_name           e_optowl     e_optoampl     e_displayazim    e_displayelev    e_notes
# +--------------+ +---+ +----+ +--------------+ +----------+ +------------+ +--------------+ +--------------+ +--------------+
# Ntsr1Cre_2019_00 1     1      Achkrbrd         nan          nan            45.0             0.0              Forgot to start
# Ntsr1Cre_2019_00 1     2      AoriTun8_opto    nan          nan            45.0             0.0              x, y = 0, -20, s
# Ntsr1Cre_2019_00 1     3      AoriTun12_opto   nan          nan            45.0             0.0              x, y = 0, -20, s
# Ntsr1Cre_2019_00 1     4      sparseNoise4     nan          nan            45.0             0.0              x, y = 0, -10, d
# Ntsr1Cre_2019_00 1     5      MAS_1400_200-500 nan          nan            45.0             0.0              5.75 s opto puls
# Ntsr1Cre_2019_00 1     6      hollymov_opto_03 nan          nan            45.0             0.0              106 deg, 1 s opt
# Ntsr1Cre_2019_00 1     7      AsparseNoise5_60 nan          nan            45.0             0.0              x, y = 0, -10, e
# Ntsr1Cre_2019_00 1     8      MAS_1403_0-300_C nan          nan            45.0             0.0              5.75 s opto puls
# Ntsr1Cre_2019_00 1     9      Aspontaneous_opt nan          nan            45.0             0.0              1 s opto pulses,
# Ntsr1Cre_2019_00 1     10     Achkrbrd         nan          nan            45.0             0.0              Much better look
# Ntsr1Cre_2019_00 1     11     AoriTun8_opto    nan          nan            45.0             0.0              x, y = 0, -20, s
# Ntsr1Cre_2019_00 1     12     AoriTun8_opto    nan          nan            45.0             0.0              x, y = 0, -20, s
# Ntsr1Cre_2019_00 2     1      AoriTun8_opto    nan          nan            60.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 2     2      AsparseNoise5_60 nan          nan            60.0             0.0              x, y = 0, 0, got
# Ntsr1Cre_2019_00 2     3      AoriTun8_opto    nan          nan            60.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 2     4      Aspontaneous_opt nan          nan            60.0             0.0              1 s opto pulses,
# Ntsr1Cre_2019_00 2     5      AoriTun12_opto   nan          nan            78.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 2     6      AsparseNoise5_60 nan          nan            78.0             0.0              x, y = 0, 0, nic
# Ntsr1Cre_2019_00 2     7      MAS_1400_200-500 nan          nan            78.0             0.0              5.75 s opto puls
# Ntsr1Cre_2019_00 2     8      hollymov_opto_03 nan          nan            78.0             0.0              106 deg, 1 s opt
# Ntsr1Cre_2019_00 2     9      AoriTun8_opto    nan          nan            78.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 3     1      AsparseNoise5_60 nan          nan            45.0             0.0              x, y = 0, 0, tai
# Ntsr1Cre_2019_00 3     2      Aspontaneous_opt nan          nan            45.0             0.0              1 s opto pulses,
# Ntsr1Cre_2019_00 3     3      AoriTun12_opto   nan          nan            45.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 3     4      MAS_1403_0-300_C nan          nan            45.0             0.0              400 trials, 5.75
# Ntsr1Cre_2019_00 3     5      AoriTun12_mov_co nan          nan            45.0             0.0              5.75 s opto puls
# Ntsr1Cre_2019_00 3     6      MAS_1400_B_ChR2  nan          nan            45.0             0.0              400 trials, 5.75
# Ntsr1Cre_2019_00 4     1      AsparseNoise5_60 nan          nan            60.0             9.46232          x, y = 0, 0, rea
# Ntsr1Cre_2019_00 4     2      Aspontaneous_opt nan          nan            60.0             9.46232          Audible opto sup
# Ntsr1Cre_2019_00 4     3      AoriTun12_opto   nan          nan            60.0             9.46232          x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 4     4      MAS_1400_200-500 nan          nan            60.0             5.14276          400 trials, 5.75
# Ntsr1Cre_2019_00 4     5      MAS_1400_PNK_ChR nan          nan            60.0             5.14276          200 trials, 5.75
# Ntsr1Cre_2019_00 4     6      MAS_1400_SHF_ChR nan          nan            60.0             5.14276          200 trials, 5.75
# Ntsr1Cre_2019_00 4     7      chirp_opto       nan          nan            60.0             9.46232          1 ms 50 Hz opto
# Ntsr1Cre_2019_00 4     8      compoundOriSfTf_ nan          nan            60.0             9.46232          1.1 s opto pulse
# Ntsr1Cre_2019_00 4     9      AoriTun8_opto    nan          nan            60.0             9.46232          x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 5     1      AsparseNoise5_60 nan          nan            15.0             0.0              x, y = 0, 0, sta
# Ntsr1Cre_2019_00 5     2      Aspontaneous_opt nan          nan            15.0             0.0              1.02 s opto puls
# Ntsr1Cre_2019_00 5     3      AoriTun12_opto   nan          nan            15.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 5     4      MAS_1400_B_ChR2  nan          nan            15.0             0.0              400 trials, 5.75
# Ntsr1Cre_2019_00 5     5      MAS_1400_B_INV_C nan          nan            15.0             0.0              200 trials, 5.75
# Ntsr1Cre_2019_00 5     6      MAS_1400_B_PNK_C nan          nan            15.0             0.0              200 trials, 5.75
# Ntsr1Cre_2019_00 5     7      MAS_1400_B_SHF_C nan          nan            15.0             0.0              400 trials (inst
# Ntsr1Cre_2019_00 5     8      hollymov_opto_03 nan          nan            15.0             0.0              106 deg, 1 s opt
# Ntsr1Cre_2019_00 5     9      AoriTun12_opto   nan          nan            15.0             0.0              x, y = 0, 0, sf=
# Ntsr1Cre_2019_00 5     10     chirp_opto       nan          nan            15.0             0.0              1 ms 50 Hz opto
# Ntsr1Cre_2019_00 6     1      AsparseNoise5_60 nan          nan            30.0             0.0              x, y = 0, 0, sta
# Ntsr1Cre_2019_00 6     2      Aspontaneous_opt nan          nan            30.0             0.0              1 s opto pulses,
# Ntsr1Cre_2019_00 6     3      Aspontaneous_opt nan          nan            30.0             0.0              1 s opto pulses,
# Ntsr1Cre_2019_00 6     4      AoriTun12_opto   nan          nan            30.0             0.0              x, y = 0, 0, sf=
#    ...
#  (Total: 221)

# %%
# Define sparse noise msekeys
msekeys = (Series.Experiment() & 'e_name LIKE "%hollymov%"').fetch(dj.key)
msekeys
# Out:
# [{'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 6},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 8},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 5, 'e': 8},
#  {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 3, 'e': 7},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 5, 'e': 8},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 6, 'e': 6},
#  {'m': 'Ntsr1Cre_2019_0008', 's': 7, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 7},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 3, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 3, 'e': 10},
#  {'m': 'Ntsr1Cre_2020_0001', 's': 4, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 2, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 3, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 4, 'e': 8},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 5, 'e': 6},
#  {'m': 'Ntsr1Cre_2020_0002', 's': 6, 'e': 6}]

# %%
HmovUnit.populate({'m': 'Ntsr1Cre_2020_0002'})

# %%
# Build mice and report duration
from datetime import datetime
start_time = datetime.now()
print(f'Start date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}\n')
    
build_dict = build(keys=[{'m':'Ntsr1Cre_2020_0001', 's':2, 'e':11}], mantables=BASICMANTABLES+HMOV_MANTABLES, autotables=BASICAUTOTABLES+HMOV_AUTOTABLES)

print(f'\nStop date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}'
      f'\n-> Duration: {datetime.now() - start_time}')

print('Error dict:\n', build_dict)
# Out:
# Start date and time: 10/26/2021, 12:27:47
#
# Hmov(): Populating Hmov() table and part tables.
# Hmov(): Found hollymov version 3 with frame shape 424x264.
# Hmov(): populating version 3.
# Hmov.VersionPars(): populating version 3, frame shape 424x264.
# Hmov.Scenes(): populating scenes for version 3.
# Hmov.ScenePars(): populating scene parameters for version 3, frame shape 424x264.
# Hmov.RandSeqs(): populating random sequences for version 3.
# Hmov.RandSeqPars(): populating random sequence parameters for version 3, frame shape 424x264.
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: dataLog
# Unit: 0it [00:00, ?it/s]
# ClusterGroups: No new units found, doing nothing...
# Stimulus:   0%|          | 0/1 [00:00<?, ?it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (23.964 Hz) too low, reverting to digital frame words
# Stimulus: 100%|██████████| 1/1 [00:07<00:00,  7.47s/it]
# Run:   0%|          | 0/1 [00:00<?, ?it/s]
# Run parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.nev
# Run: 100%|██████████| 1/1 [00:07<00:00,  7.22s/it]
# State:   0%|          | 0/6 [00:00<?, ?it/s]
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# State:  50%|█████     | 3/6 [00:00<00:00,  6.49it/s]
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# State:  83%|████████▎ | 5/6 [00:00<00:00,  6.93it/s]
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# State parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'none', 'st8_crit': 'none'}
# Skipping 'none' state for State.Trial
# State: 100%|██████████| 6/6 [00:00<00:00,  7.46it/s]
# Eye: 100%|██████████| 1/1 [00:00<00:00, 113.22it/s]
# Eye parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11}
#     Can't find file: /Volumes/mudata/behavior/Ntsr1Cre_2020_0001/s02/e11/Ntsr1Cre_2020_0001_s02_e11.eye.json
# Event:   0%|          | 0/7 [00:00<?, ?it/s]
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'bluelight'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'lick'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'lick_left'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'lick_right'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'opto1'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Found chan 'opto1'
# ON & OFF event times wrt stimulus: median: [-0.30246667  0.4359    ], stdev: [0.00015803 0.00352232]
# Event:  71%|███████▏  | 5/7 [00:01<00:00,  2.57it/s]
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'opto2'}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0001/s02/Ntsr1Cre_2020_0001_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Found chan 'opto2'
# Event: 100%|██████████| 7/7 [00:03<00:00,  2.06it/s]
# No ON/OFF transitions found in recorded event channel 'opto2'
# Event parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'ev_chan': 'opto_bi'}
# One or both bistable channels ['opto1', 'opto2'] have no populated event times
# Found chan 'opto_bi'
# No ON/OFF transitions found in recorded event channel 'opto_bi'
# Ivs: 0it [00:00, ?it/s]
# Condition:   0%|          | 0/5 [00:00<?, ?it/s]
# Condition parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Condition:  20%|██        | 1/5 [00:00<00:01,  2.44it/s]
# Condition parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Condition:  60%|██████    | 3/5 [00:00<00:00,  4.24it/s]
# Condition parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Condition parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Condition:  80%|████████  | 4/5 [00:00<00:00,  5.36it/s]
# Condition parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'st8_type': 'none', 'st8_crit': 'none'}
# Condition: 100%|██████████| 5/5 [00:01<00:00,  4.01it/s]
# TuningInfo: 0it [00:00, ?it/s]
# Tuning: 0it [00:00, ?it/s]
# VisDrive: 0it [00:00, ?it/s]
# FiringPattern:   0%|          | 0/2 [00:00<?, ?it/s]
# FiringPattern parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'fp_dtsilent': 0.07, 'fp_dtburst': 0.01}
# /Users/ybauer/miniconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# FiringPattern:  50%|█████     | 1/2 [00:00<00:00,  2.99it/s]/Users/ybauer/miniconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# FiringPattern: 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# FiringPattern parentkey: {'m': 'Ntsr1Cre_2020_0001', 's': 2, 'e': 11, 'fp_dtsilent': 0.1, 'fp_dtburst': 0.004}
# WaveShapeCluster: 0it [00:00, ?it/s]
# OptoTag: 0it [00:00, ?it/s]
# SI: 0it [00:00, ?it/s]
# HmovUnit: 0it [00:00, ?it/s]
# HmovUnit() & {'m':'Ntsr1Cre_2020_0001', 's':2} took 0:00:47.366593
#
# Stop date and time: 10/26/2021, 12:28:34
# -> Duration: 0:00:47.367162
# Error dict:
#  {'Unit': [], 'ClusterGroups': None, 'Stimulus': [], 'Run': [], 'State': [], 'Eye': [], 'Event': [], 'Ivs': [], 'Condition': [], 'TuningInfo': [], 'Tuning': [], 'VisDrive': [], 'FiringPattern': [], 'WaveShapeCluster': [], 'OptoTag': [], 'SI': [], 'HmovUnit': []}

# %%
# Time code execution
from datetime import datetime
start_time = datetime.now()
print(f'Start date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}\n')
    
build_dict = build(keys=[{'m': 'Ntsr1Cre_2020_0004'}, {'m': 'Ntsr1Cre_2020_0003'}], mantables=BASICMANTABLES+HMOV_MANTABLES, autotables=BASICAUTOTABLES)#+HMOV_AUTOTABLES)

print(f'\nStop date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}'
      f'\n-> Duration: {datetime.now() - start_time}')

print(build_dict)
# Out:
# Start date and time: 09/16/2021, 15:59:34
#
# Hmov(): Populating Hmov() table and part tables.
# Hmov(): Found hollymov version 3 with frame shape 424x264.
# Hmov(): populating version 3.
# Hmov.VersionPars(): populating version 3, frame shape 424x264.
# Hmov.Scenes(): populating scenes for version 3.
# Hmov.ScenePars(): populating scene parameters for version 3, frame shape 424x264.
# Hmov.RandSeqs(): populating random sequences for version 3.
# Hmov.RandSeqPars(): populating random sequence parameters for version 3, frame shape 424x264.
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: dataLog
# Unit:   0%|          | 0/14 [00:00<?, ?it/s]
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e01/Ntsr1Cre_2020_0003_s02_e01.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e02/Ntsr1Cre_2020_0003_s02_e02.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e03/Ntsr1Cre_2020_0003_s02_e03.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e04/Ntsr1Cre_2020_0003_s02_e04.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e05/Ntsr1Cre_2020_0003_s02_e05.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_e06/Ntsr1Cre_2020_0003_s02_e06.ptcs
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/cooked/Ntsr1Cre_2020_0003_s02_
/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e11.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e11.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# WARNING: expected (1) and measured (-1) TTL logic mismatch for chan 'photodiode', using expected logic
# /Users/ybauer/code/djd/djd/signal.py:615: RuntimeWarning: Mean of empty slice.
#   meanriseinterval = riseintervals.mean()
# invalid value encountered in double_scalars
# Stimulus:   8%|▊         | 11/136 [00:33<14:33,  6.99s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 12}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.xml
# Stimulus.Hmov(): Fill table.
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Stimulus.HmovScenes(): Fill table for  {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 12}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (61.648) vs trial on time from photodiode signal (61.648): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (101.727) vs trial on time from photodiode signal (101.727): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (282.048) vs trial on time from photodiode signal (282.081): -0.033 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (322.160) vs trial on time from photodiode signal (322.160): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (502.481) vs trial on time from photodiode signal (502.514): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (542.592) vs trial on time from photodiode signal (542.592): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (722.913) vs trial on time from photodiode signal (722.963): -0.050 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (763.042) vs trial on time from photodiode signal (763.042): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (943.362) vs trial on time from photodiode signal (943.396): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (983.441) vs trial on time from photodiode signal (983.475): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1163.795) vs trial on time from photodiode signal (1163.829): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1203.873) vs trial on time from photodiode signal (1203.907): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1384.194) vs trial on time from photodiode signal (1384.261): -0.067 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1424.306) vs trial on time from photodiode signal (1424.340): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1604.627) vs trial on time from photodiode signal (1604.694): -0.067 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Difference between Expo-recorded trial on time (1644.739) vs trial on time from photodiode signal (1644.772): -0.033 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e12.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# Stimulus:   9%|▉         | 12/136 [00:50<20:40, 10.01s/it]
# 	Difference between Expo-recorded trial on time (1825.060) vs trial on time from photodiode signal (1825.126): -0.066 (s)
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 13}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e13.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e13.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (26.814 Hz) too low, reverting to digital frame words
# Stimulus:  10%|▉         | 13/136 [00:58<19:45,  9.64s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 14}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e14.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e14.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (27.314 Hz) too low, reverting to digital frame words
# Stimulus:  10%|█         | 14/136 [01:03<16:41,  8.21s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 15}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e15.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e15.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (26.814 Hz) too low, reverting to digital frame words
# Stimulus:  11%|█         | 15/136 [01:11<16:29,  8.18s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 16}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e16.xml
# Extra content at the end of the document, line 21, column 3 (<string>, line 21)
# Stimulus:  12%|█▏        | 16/136 [01:14<12:58,  6.49s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 17}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e17.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e17.ns3
# Using metadata file 'A1x32_edge.ns6.json'
# Setting probe type: 'A1x32_edge'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (23.965 Hz) too low, reverting to digital frame words
# Stimulus:  12%|█▎        | 17/136 [01:20<12:18,  6.21s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 1}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e01.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 2}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e02.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e02.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  14%|█▍        | 19/136 [01:21<07:08,  3.66s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 3}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e03.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e03.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  15%|█▍        | 20/136 [01:22<05:53,  3.05s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 4}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e04.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e04.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.768 Hz) too low, reverting to digital frame words
# Stimulus:  15%|█▌        | 21/136 [01:24<05:11,  2.71s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 5}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e05.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e05.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  16%|█▌        | 22/136 [01:25<04:25,  2.33s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 6}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e06.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e06.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.768 Hz) too low, reverting to digital frame words
# Stimulus:  17%|█▋        | 23/136 [01:27<04:09,  2.21s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 7}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e07.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 8}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e08.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e08.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.762 Hz) too low, reverting to digital frame words
# Stimulus:  18%|█▊        | 25/136 [01:29<03:09,  1.70s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 9}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e09.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e09.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# Stimulus:
(s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (983.458) vs trial on time from photodiode signal (983.458): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1163.778) vs trial on time from photodiode signal (1163.812): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1203.857) vs trial on time from photodiode signal (1203.890): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1384.211) vs trial on time from photodiode signal (1384.245): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1424.290) vs trial on time from photodiode signal (1424.323): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1604.643) vs trial on time from photodiode signal (1604.677): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (1644.722) vs trial on time from photodiode signal (1644.755): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# Stimulus:  30%|███       | 41/136 [03:08<10:01,  6.33s/it]
# 	Difference between Expo-recorded trial on time (1825.043) vs trial on time from photodiode signal (1825.110): -0.067 (s)
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 12}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e12.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e12.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.762 Hz) too low, reverting to digital frame words
# Discarded 1 invalid ball packet(s)
# Stimulus:  31%|███       | 42/136 [03:10<08:02,  5.14s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 13}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e13.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e13.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (27.316 Hz) too low, reverting to digital frame words
# Stimulus:  32%|███▏      | 43/136 [03:16<08:08,  5.25s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 14}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e14.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e14.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (24.001 Hz) too low, reverting to digital frame words
# Stimulus:  32%|███▏      | 44/136 [03:17<06:28,  4.23s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 1}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e01.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e01.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# Stimulus:  33%|███▎      | 45/136 [03:22<06:43,  4.44s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 2}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e02.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e02.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# Stimulus:  34%|███▍      | 46/136 [03:45<14:53,  9.93s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 3}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e03.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 4}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e04.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e04.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  35%|███▌      | 48/136 [03:47<08:26,  5.75s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 5}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e05.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e05.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  36%|███▌      | 49/136 [03:48<06:42,  4.63s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 6}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e06.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e06.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (17.139 Hz) too low, reverting to digital frame words
# Stimulus:  37%|███▋      | 50/136 [03:49<05:20,  3.73s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 7}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e07.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 8}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e08.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e08.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.768 Hz) too low, reverting to digital frame words
# Stimulus:  38%|███▊      | 52/136 [03:51<03:30,  2.50s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 9}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e09.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e09.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.762 Hz) too low, reverting to digital frame words
# Stimulus:  39%|███▉      | 53/136 [03:53<03:20,  2.41s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 10}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e10.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e10.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Rise/fall times mismatch or mean photodiode flicker frequency (22.762 Hz) too low, reverting to digital frame words
# Stimulus:  40%|███▉      | 54/136 [03:55<03:06,  2.28s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.xml
# Stimulus.Hmov(): Fill table.
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# Stimulus.HmovScenes(): Fill table for  {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (61.641) vs trial on time from photodiode signal (61.641): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (101.721) vs trial on time from photodiode signal (101.721): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (282.075) vs trial on time from photodiode signal (282.075): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (322.153) vs trial on time from photodiode signal (322.153): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (502.474) vs trial on time from photodiode signal (502.507): -0.034 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (542.586) vs trial on time from photodiode signal (542.586): 0.000 (s)
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e11.ns3
# Found 0 ns6.json files, ignoring them
# WARNING: assuming probe A1x32 was used in this recording
# Setting probe type: 'A1x32'
# 	Difference between Expo-recorded trial on time (722.906) vs trial on time from photodiode signal (722.939): -0.034 (s)
# ...
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 51, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 52, 'si_name': 'niell_DSI'}
# SI:  80%|███████▉  | 244/306 [00:12<00:04, 15.18it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 52, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 56, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 56, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 58, 'si_name': 'niell_DSI'}
# SI:  81%|████████  | 248/306 [00:12<00:03, 16.62it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 58, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 66, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 66, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 68, 'si_name': 'niell_DSI'}
# SI:  82%|████████▏ | 250/306 [00:12<00:03, 14.33it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 6, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 68, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 3, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 3, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 5, 'si_name': 'niell_DSI'}
# SI:  83%|████████▎ | 255/306 [00:13<00:03, 14.27it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 5, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 6, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 6, 'si_name': 'vector_OSI'}
# SI:  84%|████████▍ | 257/306 [00:13<00:03, 15.51it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 7, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 7, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 9, 'si_name': 'niell_DSI'}
# SI:  85%|████████▌ | 261/306 [00:13<00:02, 15.77it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 9, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 11, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 11, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 13, 'si_name': 'niell_DSI'}
# SI:  87%|████████▋ | 265/306 [00:13<00:02, 16.27it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 13, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 16, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 16, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 18, 'si_name': 'niell_DSI'}
# SI:  88%|████████▊ | 269/306 [00:14<00:02, 17.04it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 18, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 20, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 20, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 21, 'si_name': 'niell_DSI'}
# SI:  89%|████████▉ | 273/306 [00:14<00:02, 15.06it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 21, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 25, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 25, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 27, 'si_name': 'niell_DSI'}
# SI:  91%|█████████ | 277/306 [00:14<00:01, 15.63it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 27, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 31, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 31, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 32, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 32, 'si_name': 'vector_OSI'}
# SI:  92%|█████████▏| 281/306 [00:14<00:01, 21.27it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 39, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 39, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 40, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 40, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 42, 'si_name': 'niell_DSI'}
# SI:  94%|█████████▍| 288/306 [00:14<00:00, 21.76it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 42, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 43, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 43, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 45, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 45, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 47, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 47, 'si_name': 'vector_OSI'}
# SI:  95%|█████████▌| 292/306 [00:15<00:00, 25.11it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 48, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 48, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 51, 'si_name': 'niell_DSI'}
# SI:  98%|█████████▊| 299/306 [00:15<00:00, 23.98it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 51, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 52, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 52, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 56, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 56, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 58, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 58, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 66, 'si_name': 'niell_DSI'}
# SI: 100%|██████████| 306/306 [00:15<00:00, 19.53it/s]
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 66, 'si_name': 'vector_OSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 68, 'si_name': 'niell_DSI'}
# SI parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 7, 'ivs_order': 'grat_orientation, opto1', 'tun_model': 'sum_of_gaussians', 'st8_type': 'none', 'st8_crit': 'none', 'u': 68, 'si_name': 'vector_OSI'}
# SplineLNP() & {'m': 'Ntsr1Cre_2020_0001'} took 0:27:02.840945
#
# WARNING: Errors were found but were suppressed, check returned dictionary
#
# Stop date and time: 09/16/2021, 16:26:37
# -> Duration: 0:27:02.841668
# {'Unit': [({'m': 'Ntsr1Cre_2020_0004', 's': 4}, "RuntimeError: No experiment subdirectories found in 'cooked' path /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s04/cooked")], 'ClusterGroups': None, 'Stimulus': [({'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 4}, 'ValueError: Unequal number of grating textures (0) and surfaces (12) found for experiment titrate_light_intensity_MASmov_doricLED_465nm_500mum_063NA'), ({'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 11}, 'FloatingPointError: invalid value encountered in double_scalars'), ({'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 16}, 'XMLSyntaxError: Extra content at the end of the document, line 21, column 3 (<string>, line 21)'), ({'m': 'Ntsr1Cre_2020_0004', 's': 4, 'e': 17}, 'XMLSyntaxError: Extra content at the end of the document, line 21, column 3 (<string>, line 21)'), ({'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 15}, 'XMLSyntaxError: Extra content at the end of the document, line 21, column 3 (<string>, line 21)')], 'Run': [], 'State': [], 'Eye': [], 'Event': [], 'Ivs': [], 'Condition': [], 'TuningInfo': [], 'Tuning': [], 'VisDrive': [], 'FiringPattern': [], 'WaveShapeCluster': [], 'OptoTag': [], 'SI': []}

# %%
# Time code execution
from datetime import datetime
start_time = datetime.now()
print(f'Start date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}\n')
    
build_dict = build(keys=mouse_ids, mantables=BASICMANTABLES+HMOV_MANTABLES, autotables=BASICAUTOTABLES+HMOV_AUTOTABLES)

print(f'\nStop date and time: {datetime.now().strftime("%m/%d/%Y, %H:%M:%S")}'
      f'\n-> Duration: {datetime.now() - start_time}')

print(build_dict)
# Out:
# Start date and time: 07/07/2021, 23:28:18
#
# Hmov(): Populating Hmov() table and part tables.
# Hmov(): Found hollymov version 3 with frame shape 424x264.
# Hmov(): populating version 3.
# Hmov.VersionPars(): populating version 3, frame shape 424x264.
# Hmov.Scenes(): populating scenes for version 3.
# Hmov.ScenePars(): populating scene parameters for version 3, frame shape 424x264.
# Hmov.RandSeqs(): populating random sequences for version 3.
# Hmov.RandSeqPars(): populating random sequence parameters for version 3, frame shape 424x264.
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0002.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0003.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0007.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0008.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0002.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: basic
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0002.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0003.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0007.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0008.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0002.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: dailyPhysiology
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0002.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0003.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0007.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2019_0008.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0001.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0002.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0003.xlsx: dataLog
# /Volumes/mudata/logs/Ntsr1Cre/Ntsr1Cre_2020_0004.xlsx: dataLog
#   0%|          | 0/24 [00:00<?, ?it/s]ERROR:datajoint.autopopulate:Sort files not found: ['/Volumes/mudata/exp/Ntsr1Cre_2019_0003/s02/cooked/Ntsr1Cre_2019_0003_s02.track.json', '/Volumes/mudata/exp/Ntsr1Cre_2019_0003/s02/cooked/Ntsr1Cre_2019_0003_s02.track.sort']
#  54%|█████▍    | 13/24 [00:00<00:00, 118.29it/s]
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s01/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s04/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2}
# Missing one or more experiment subfolders in `cooked` path /Volumes/mudata/exp/Ntsr1Cre_2019_0003/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0007/s01/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0007/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 3}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0007/s03/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0008', 's': 1}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0008/s01/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0008', 's': 2}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0008/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0008', 's': 4}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0008/s04/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2019_0008', 's': 8}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2019_0008/s08/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0002', 's': 2}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0002/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 6}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s06/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 7}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s07/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 1}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s01/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 2}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s02/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 3}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s03/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 4}
# ERROR:datajoint.autopopulate:No experiment subdirectories found in 'cooked' path /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s04/cooked
# 100%|██████████| 24/24 [00:00<00:00, 107.60it/s]
# Missing one or more experiment subfolders in `cooked` path /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s04/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 5}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s05/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 7}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s07/cooked
# Unit parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 8}
# Series `cooked` path does not exist: /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s08/cooked
#   0%|          | 0/18 [00:00<?, ?it/s]
# ClusterGroups: No new units found, doing nothing...
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 9}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s01/Ntsr1Cre_2019_0002_s01_e09.xml
# ERROR:datajoint.autopopulate:Unequal number of grating textures (4) and surfaces (6) found for experiment LGN_Chirp_opto
#   6%|▌         | 1/18 [00:00<00:06,  2.61it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 1}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s02/Ntsr1Cre_2019_0002_s02_e01.xml
# /Volumes/mudata/exp/Ntsr1Cre_2019_0002/s02/Ntsr1Cre_2019_0002_s02_e01.ns3
# ERROR:datajoint.autopopulate:Onset of photodiode trace is too high, trace might be corrupted. Experiment will be skipped
#  11%|█         | 2/18 [00:05<00:49,  3.12s/it]ERROR:datajoint.autopopulate:fetch1 should only return one tuple. 0 tuples were found
#  17%|█▋        | 3/18 [00:05<00:26,  1.78s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 8}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0003/s02/Ntsr1Cre_2019_0003_s02_e08.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 9}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0003/s02/Ntsr1Cre_2019_0003_s02_e09.xml
# ERROR:datajoint.autopopulate:fetch1 should only return one tuple. 0 tuples were found
#  22%|██▏       | 4/18 [00:05<00:15,  1.14s/it]ERROR:datajoint.autopopulate:fetch1 should only return one tuple. 0 tuples were found
#  28%|██▊       | 5/18 [00:05<00:10,  1.28it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 5}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0003/s04/Ntsr1Cre_2019_0003_s04_e05.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 9}
# /Volumes/mudata/exp/Ntsr1Cre_2019_0003/s04/Ntsr1Cre_2019_0003_s04_e09.xml
# ERROR:datajoint.autopopulate:fetch1 should only return one tuple. 0 tuples were found
#  33%|███▎      | 6/18 [00:06<00:06,  1.77it/s]ERROR:datajoint.autopopulate:Unequal number of grating textures (0) and surfaces (12) found for experiment titrate_light_intensity_MASmov_doricLED_465nm_500mum_063NA
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 4}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e04.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 2, 'e': 11}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e11.xml
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s02/Ntsr1Cre_2020_0003_s02_e11.ns3
# ERROR:datajoint.autopopulate:Not enough riseis found given the Expo stimulus time ranges. File corrupt?
#  44%|████▍     | 8/18 [00:21<00:39,  3.97s/it]ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  50%|█████     | 9/18 [00:21<00:26,  2.98s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 3, 'e': 12}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s03/Ntsr1Cre_2020_0003_s03_e12.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 4}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e04.xml
# ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  56%|█████▌    | 10/18 [00:21<00:17,  2.22s/it]ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  61%|██████    | 11/18 [00:21<00:11,  1.64s/it]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 5}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e05.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 4, 'e': 10}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s04/Ntsr1Cre_2020_0003_s04_e10.xml
# ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  67%|██████▋   | 12/18 [00:21<00:07,  1.21s/it]ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  72%|███████▏  | 13/18 [00:21<00:04,  1.11it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 4}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e04.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 5, 'e': 6}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s05/Ntsr1Cre_2020_0003_s05_e06.xml
# ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  78%|███████▊  | 14/18 [00:21<00:02,  1.48it/s]ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  83%|████████▎ | 15/18 [00:22<00:01,  1.94it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0003', 's': 7, 'e': 1}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0003/s07/Ntsr1Cre_2020_0003_s07_e01.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 4, 'e': 2}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s04/Ntsr1Cre_2020_0004_s04_e02.xml
# ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  89%|████████▉ | 16/18 [00:22<00:00,  2.47it/s]ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
#  94%|█████████▍| 17/18 [00:22<00:00,  3.01it/s]
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 6, 'e': 3}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s06/Ntsr1Cre_2020_0004_s06_e03.xml
# Stimulus parentkey: {'m': 'Ntsr1Cre_2020_0004', 's': 7, 'e': 3}
# /Volumes/mudata/exp/Ntsr1Cre_2020_0004/s07/Ntsr1Cre_2020_0004_s07_e03.xml
# ERROR:datajoint.autopopulate:Spatial frequency x and y are not the same for stimulus 0
# 100%|██████████| 18/18 [00:22<00:00,  1.25s/it]
# 0it [00:00, ?it/s]
#   2%|▏         | 13/551 [00:00<00:04, 125.29it/s]
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 10, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
#   7%|▋         | 41/551 [00:00<00:03, 129.48it/s]
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 1, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
#  13%|█▎        | 69/551 [00:00<00:03, 128.21it/s]
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 2, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 9, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 10, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 9, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
#  17%|█▋        | 96/551 [00:00<00:03, 129.21it/s]
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 9, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 9, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
#  22%|██▏       | 122/551 [00:00<00:03, 128.59it/s]
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 6, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 7, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 8, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 9, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 10, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 3, 'e': 11, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed < 0.25).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.5'}
# Mismatch between run_type='none' and state_type='ball', skipping
#  27%|██▋       | 147/551 [00:01<00:06, 64.42it/s]
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 1, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 2, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 3, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 4, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 4, 'e': 5, 'st8_type': 'ball', 'st8_crit': '(run_speed > 1).mean() > 0.8'}
# Mismatch between run_type='none' and state_type='ball', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 9, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 10, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0002', 's': 5, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
#  31%|███       | 171/551 [00:01<00:04, 82.70it/s]
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 10, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 2, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0003', 's': 4, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 9, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 10, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 11, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 1, 'e': 12, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
#  35%|███▌      | 195/551 [00:02<00:03, 97.55it/s]
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 5, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 6, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 7, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 8, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 2, 'e': 9, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 3, 'e': 1, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 3, 'e': 2, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 3, 'e': 3, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# State parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 3, 'e': 4, 'st8_type': 'disk', 'st8_crit': '(run_speed >= 20).mean() > 0.8'}
# Mismatch between run_type='ball' and state_type='disk', skipping
# ...
# TEST: get_hmov_array()
# stimulus_train_exp_order: (43200, 16, 25) 138.23999999999998
# stimulus_test: (1200, 16, 25) 3.84
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# stimulus_train: (64800, 16, 25) 207.35999999999999
# stimulus_validation: (21600, 16, 25) 69.11999999999999
# stimulus_test_interp: (2400, 16, 25) 7.68
# memory usage before get_stimulus_design_matrix()
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                 y_test_repeats:  200.0 B
#                             gc:   88.0 B
#                           self:   64.0 B
#                           data:   64.0 B
#                          param:   59.0 B
#             PARS_STIM_INTERP1D:   56.0 B
#             PARS_RESP_INTERP1D:   56.0 B
# X_train: (64800, 8000) 414.71999999999997
# X_validation: (21600, 8000) 138.23999999999998
# X_test: (2400, 8000) 15.36
# resp_train: (64800,) 0.5184
# resp_val: (21600,) 0.17279999999999998
# resp_test: (2400,) 0.0192
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                splinelnp_entry:  376.0 B
# TEST: SplineLNP.make()(): initialize model
# Duration for model initialization: 0:01:24.810533
# TEST: SplineLNP.make(): initialize model filters
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                       datetime:  400.0 B
#                      parentkey:  376.0 B
# Duration for filter initialization: 0:01:24.829262
# TEST: SplineLNP.make()(): fit model
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     8.887	  1056.955	   585.345	    -0.008	     0.022
#   200	    57.069	   380.201	   363.441	     0.025	    -0.028
#   400	   106.154	   387.063	   388.766	     0.029	    -0.020
#   600	   156.149	   387.079	   406.789	     0.028	    -0.015
#   800	   206.162	   387.254	   422.344	     0.027	    -0.013
# Stop: reached 1000 steps.
#
# Total time elapsed: 255.866 s.
# Duration for model fitting: 0:06:00.035444
# TEST: SplineLNP.make()(): model predictions
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Duration for model predictions: 0:07:33.904075
# TEST: SplineLNP.make(): make table entries
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                     yhat_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                yhat_validation: 168.8 KiB
#                      resp_test: 18.8 KiB
#                  yhat_test_rep: 18.8 KiB
#                      yhat_test: 18.8 KiB
# SplineLNP.Eval() parentkey: {'s': 6, 'spl_paramset': 603, 'e': 9, 'm': 'Ntsr1Cre_2019_0007', 'u': 19, 'spl_stim': 'hmov'}
# dir(): ['PARS_RESP_INTERP1D', 'PARS_STIM_INTERP1D', 'PSTH_BINW', 'datetime', 'dfs', 'dims', 'gc', 'height_frame', 'hm_info', 'hmov_fs', 'i', 'name', 'nreps', 'param', 'parentkey', 'pars', 'pdb', 'resp_test', 'resp_train', 'resp_val', 'self', 'shift_factor_h', 'shift_factor_x', 'size', 'splineLNPbehavior', 'start_time', 'weight', 'width_frame']
#   9%|▉         | 77/855 [8:17:27<92:53:41, 429.85s/it]
# TEST: SplineLNP.make(): start
# dir(): ['parentkey', 'self']
# dir(): ['gc', 'parentkey', 'self']
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 20, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# TEST: get_hmov_data()
# TEST: get_hmov_array()
# stimulus_train_exp_order: (43200, 16, 25) 138.23999999999998
# stimulus_test: (1200, 16, 25) 3.84
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# stimulus_train: (64800, 16, 25) 207.35999999999999
# stimulus_validation: (21600, 16, 25) 69.11999999999999
# stimulus_test_interp: (2400, 16, 25) 7.68
# memory usage before get_stimulus_design_matrix()
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                 y_test_repeats:  200.0 B
#                             gc:   88.0 B
#                           self:   64.0 B
#                           data:   64.0 B
#                          param:   59.0 B
#             PARS_STIM_INTERP1D:   56.0 B
#             PARS_RESP_INTERP1D:   56.0 B
# X_train: (64800, 8000) 414.71999999999997
# X_validation: (21600, 8000) 138.23999999999998
# X_test: (2400, 8000) 15.36
# resp_train: (64800,) 0.5184
# resp_val: (21600,) 0.17279999999999998
# resp_test: (2400,) 0.0192
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                splinelnp_entry:  376.0 B
# TEST: SplineLNP.make()(): initialize model
# Duration for model initialization: 0:01:24.686445
# TEST: SplineLNP.make(): initialize model filters
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                       datetime:  400.0 B
#                      parentkey:  376.0 B
# Duration for filter initialization: 0:01:24.704734
# TEST: SplineLNP.make()(): fit model
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     8.964	-133770.487	-49924.453	     0.161	     0.160
#   200	    57.122	-221138.624	-82948.740	     0.426	     0.324
#   400	   106.285	-221526.063	-83171.145	     0.429	     0.324
#   600	   156.307	-221562.154	-83193.355	     0.430	     0.325
#   800	   206.284	-221584.666	-83196.638	     0.431	     0.325
# Stop: reached 1000 steps.
#
# Total time elapsed: 256.015 s.
# Duration for model fitting: 0:06:00.060658
# TEST: SplineLNP.make()(): model predictions
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Duration for model predictions: 0:07:33.664934
# TEST: SplineLNP.make(): make table entries
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                     yhat_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                yhat_validation: 168.8 KiB
#                      resp_test: 18.8 KiB
#                  yhat_test_rep: 18.8 KiB
#                      yhat_test: 18.8 KiB
# SplineLNP.Eval() parentkey: {'s': 6, 'spl_paramset': 603, 'e': 9, 'm': 'Ntsr1Cre_2019_0007', 'u': 20, 'spl_stim': 'hmov'}
# dir(): ['PARS_RESP_INTERP1D', 'PARS_STIM_INTERP1D', 'PSTH_BINW', 'datetime', 'dfs', 'dims', 'gc', 'height_frame', 'hm_info', 'hmov_fs', 'i', 'name', 'nreps', 'param', 'parentkey', 'pars', 'pdb', 'resp_test', 'resp_train', 'resp_val', 'self', 'shift_factor_h', 'shift_factor_x', 'size', 'splineLNPbehavior', 'start_time', 'weight', 'width_frame']
#   9%|▉         | 78/855 [8:25:09<94:51:08, 439.47s/it]
# TEST: SplineLNP.make(): start
# dir(): ['parentkey', 'self']
# dir(): ['gc', 'parentkey', 'self']
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 21, 'spl_paramset': 603, 'spl_stim': 'hmov'}
# TEST: get_hmov_data()
# TEST: get_hmov_array()
# stimulus_train_exp_order: (43200, 16, 25) 138.23999999999998
# stimulus_test: (1200, 16, 25) 3.84
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# stimulus_train: (64800, 16, 25) 207.35999999999999
# stimulus_validation: (21600, 16, 25) 69.11999999999999
# stimulus_test_interp: (2400, 16, 25) 7.68
# memory usage before get_stimulus_design_matrix()
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                 y_test_repeats:  200.0 B
#                             gc:   88.0 B
#                           self:   64.0 B
#                           data:   64.0 B
#                          param:   59.0 B
#             PARS_STIM_INTERP1D:   56.0 B
#             PARS_RESP_INTERP1D:   56.0 B
# X_train: (64800, 8000) 414.71999999999997
# X_validation: (21600, 8000) 138.23999999999998
# X_test: (2400, 8000) 15.36
# resp_train: (64800,) 0.5184
# resp_val: (21600,) 0.17279999999999998
# resp_test: (2400,) 0.0192
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                splinelnp_entry:  376.0 B
# TEST: SplineLNP.make()(): initialize model
# Duration for model initialization: 0:01:24.408178
# TEST: SplineLNP.make(): initialize model filters
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                       datetime:  400.0 B
#                      parentkey:  376.0 B
# Duration for filter initialization: 0:01:24.427038
# TEST: SplineLNP.make()(): fit model
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
#     0	     8.987	-41361.744	 -8618.610	     0.049	     0.005
#   200	    57.160	-61573.916	-11920.754	     0.223	     0.116
#   400	   106.209	-61601.868	-11929.575	     0.224	     0.118
#   600	   156.140	-61611.889	-11933.420	     0.225	     0.119
#   800	   206.121	-61614.691	-11933.295	     0.226	     0.120
# Stop: reached 1000 steps.
#
# Total time elapsed: 255.841 s.
# Duration for model fitting: 0:05:59.591449
# TEST: SplineLNP.make()(): model predictions
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#              splineLNPbehavior:  3.0 KiB
#                           pars:  1.2 KiB
#                splinelnp_entry:  656.0 B
#                       datetime:  400.0 B
# Duration for model predictions: 0:07:33.258391
# TEST: SplineLNP.make(): make table entries
#                        X_train:  3.9 GiB
#                   X_validation:  1.3 GiB
#                         X_test: 146.5 MiB
#                     resp_train: 506.3 KiB
#                     yhat_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                yhat_validation: 168.8 KiB
#                      resp_test: 18.8 KiB
#                  yhat_test_rep: 18.8 KiB
#                      yhat_test: 18.8 KiB
# SplineLNP.Eval() parentkey: {'s': 6, 'spl_paramset': 603, 'e': 9, 'm': 'Ntsr1Cre_2019_0007', 'u': 21, 'spl_stim': 'hmov'}
# dir(): ['PARS_RESP_INTERP1D', 'PARS_STIM_INTERP1D', 'PSTH_BINW', 'datetime', 'dfs', 'dims', 'gc', 'height_frame', 'hm_info', 'hmov_fs', 'i', 'name', 'nreps', 'param', 'parentkey', 'pars', 'pdb', 'resp_test', 'resp_train', 'resp_val', 'self', 'shift_factor_h', 'shift_factor_x', 'size', 'splineLNPbehavior', 'start_time', 'weight', 'width_frame']
#   9%|▉         | 79/855 [8:32:53<96:18:27, 446.79s/it]
# TEST: SplineLNP.make(): start
# dir(): ['parentkey', 'self']
# dir(): ['gc', 'parentkey', 'self']
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 1, 'spl_paramset': 604, 'spl_stim': 'hmov'}
# TEST: get_hmov_data()
# TEST: get_hmov_array()
# stimulus_train_exp_order: (43200, 32, 51) 564.0192
# stimulus_test: (1200, 32, 51) 15.6672
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# TEST: upsample_movie()
# stimulus_train: (64800, 32, 51) 846.0287999999999
# stimulus_validation: (21600, 32, 51) 282.0096
# stimulus_test_interp: (2400, 32, 51) 31.3344
# memory usage before get_stimulus_design_matrix()
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                 y_test_repeats:  200.0 B
#                             gc:   88.0 B
#                           self:   64.0 B
#                           data:   64.0 B
#                          param:   59.0 B
#             PARS_STIM_INTERP1D:   56.0 B
#             PARS_RESP_INTERP1D:   56.0 B
# X_train: (64800, 32640) 1692.0575999999999
# X_validation: (21600, 32640) 564.0192
# X_test: (2400, 32640) 62.6688
# resp_train: (64800,) 0.5184
# resp_val: (21600,) 0.17279999999999998
# resp_test: (2400,) 0.0192
#                        X_train: 15.8 GiB
#                   X_validation:  5.3 GiB
#                         X_test: 597.7 MiB
#                     resp_train: 506.3 KiB
#                       resp_val: 168.8 KiB
#                      resp_test: 18.8 KiB
#                           pars:  1.2 KiB
#                      parentkey:  376.0 B
#                        hm_info:  376.0 B
#                splinelnp_entry:  376.0 B
# TEST: SplineLNP.make()(): initialize model

# %% [markdown]
# ## Check DB tables

# %%
run -im djd.main -- --dbname=dj_hmov --user=execute
# Out:
# Enter MySQL password for 'execute':  ··············
# Connecting execute@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'execute@10.153.173.165'

# %%
Mouse()
# Out:
# *m               m_strain      m_genotype     m_dob          m_sex     m_craniox     m_cranioy     m_refx      m_refy     m_notes          m_protocol       m_ts
# +--------------+ +-----------+ +------------+ +------------+ +-------+ +-----------+ +-----------+ +---------+ +--------+ +--------------+ +--------------+ +--------------+
# Ntsr1Cre_2019_00 Ntsr1-Cre     +/-            2019-04-05     M         -2.3          -2.3          midline     bregma     Inject stGtACR2  ROB-55.2Vet-2532 2021-01-28 18:38
# Ntsr1Cre_2019_00 Ntsr1-Cre     +/-            2019-09-25     M         -2.3          -2.3          midline     bregma     Inject stGtACR2  ROB-55.2Vet-2532 2021-01-28 18:38
# Ntsr1Cre_2020_00 Ntsr1-Cre     -/-            2019-10-17     M         -3.28         -2.35         midline     bregma     purpose: CONTROL ROB-55.2-2532.Ve 2021-01-28 18:38
# Ntsr1Cre_2020_00 Ntsr1-Cre     +/-            2020-03-29     M         -3.28         -2.3          midline     bregma     purpose: silenci ROB-55.2-2532.Ve 2021-01-28 18:38
# Ntsr1Cre_2020_00 Ntsr1-Cre     +/-            2020-05-14     M         -3.28         -2.3          midline     bregma     purpose: silenci ROB-55.2-2532.Ve 2021-01-28 18:38
# Ntsr1Cre_2020_00 Ntsr1-Cre     +/-            2020-08-26     F         -3.28         -2.3          midline     bregma     purpose: silenci ROB-55.2-2532.Ve 2021-01-28 18:38
#  (Total: 6)

# %%
HmovUnit()
# Out:
# *m               *s    *e    *u     hm_version     hm_seq_num     hmu_fr_mean_e    hmu_fr_var_e     hmu_fr_mean_stim hmu_fr_mean_stim hmu_fr_var_stim_ hmu_fr_mean_stim hmu_fr_var_stim_ hmu_fr_mean_spon hmu_fr_var_spont hmu_fr_mean_spon hmu_fr_var_spont hmu_omi_e       hmu_omi_stim     hmu_omi_spont    hmu_oracle      hmu_explainable_ hmu_sta_co hmu_ts
# +--------------+ +---+ +---+ +----+ +------------+ +------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +--------------+ +-------------+ +--------------+ +--------------+ +-------------+ +--------------+ +--------+ +--------------+
# Ntsr1Cre_2019_00 6     9     1      3              1              3.18793          0.0994869        3.17508          3.13499          0.149016         3.24005          0.170831         2.99948          2.04659          3.14379          2.82636          0.0173299       0.0164793        0.0234916        0.066431        0.00664913       =BLOB=     2021-01-28 20:15
# Ntsr1Cre_2019_00 6     9     2      3              1              0.314107         0.0052918        0.326602         0.270756         0.00755632       0.356787         0.0122512        0.331958         0.129172         0.620805         0.563935         0.155874        0.137091         0.303167         nan             0.00166146       =BLOB=     2021-01-28 20:15
# Ntsr1Cre_2019_00 6     9     3      3              1              0.715252         0.0153576        0.723626         0.717029         0.0267331        0.713503         0.0274663        0.34737          0.129172         0.647965         0.212308         0.0046118       -0.00246537      0.302003         0.155819        0.00275096       =BLOB=     2021-01-28 20:15
# Ntsr1Cre_2019_00 6     9     4      3              1              0.219647         0.00361065       0.225128         0.192709         0.00571924       0.246167         0.00748712       0.260824         0.185227         0.471424         0.208015         0.142684        0.121808         0.287607         nan             0.00179068       =BLOB=     2021-01-28 20:15
# Ntsr1Cre_2019_00 6     9     5      3              1              0.484936         0.00747455       0.48519          0.502309         0.0123575        0.467831         0.0168628        0.426803         0.135372         0.561634         0.166036         -0.0261131      -0.0355391       0.136408         nan             0.00149436       =BLOB=     2021-01-28 20:15
# Ntsr1Cre_2019_00 7     6     3      3              1              1.13677          0.0340531        1.16944          1.12093          0.0746309        1.15237          0.0448727        1.18201          1.17472          1.16498          0.744917         0.0106961       0.0138278        -0.00725569      0.157817        0.0040068        =BLOB=     2021-01-28 20:20
#    ...
#  (Total: 159)

# %%
SplineLNP()
# Out:
# *m               *s    *e    *u     *spl_paramset    spl_n_basis     spl_b      spl_w_opt  spl_h      spl_pred_t spl_pred_t spl_pred_t spl_ts
# +--------------+ +---+ +---+ +----+ +--------------+ +-------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------------+
# Ntsr1Cre_2019_00 6     9     1      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:32
# Ntsr1Cre_2019_00 6     9     1      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:23
# Ntsr1Cre_2019_00 6     9     2      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:35
# Ntsr1Cre_2019_00 6     9     2      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:26
# Ntsr1Cre_2019_00 6     9     3      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:38
# Ntsr1Cre_2019_00 6     9     3      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:29
# Ntsr1Cre_2019_00 6     9     4      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:41
# Ntsr1Cre_2019_00 6     9     4      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:30
# Ntsr1Cre_2019_00 6     9     5      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:44
# Ntsr1Cre_2019_00 6     9     5      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:32
# Ntsr1Cre_2019_00 6     9     7      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:46
# Ntsr1Cre_2019_00 6     9     7      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:35
# Ntsr1Cre_2019_00 6     9     8      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:49
# Ntsr1Cre_2019_00 6     9     8      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:38
# Ntsr1Cre_2019_00 6     9     9      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:50
# Ntsr1Cre_2019_00 6     9     9      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:41
# Ntsr1Cre_2019_00 6     9     10     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:53
# Ntsr1Cre_2019_00 6     9     10     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:44
# Ntsr1Cre_2019_00 6     9     11     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:55
# Ntsr1Cre_2019_00 6     9     11     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:47
# Ntsr1Cre_2019_00 6     9     12     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 20:58
# Ntsr1Cre_2019_00 6     9     12     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:49
# Ntsr1Cre_2019_00 6     9     13     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:01
# Ntsr1Cre_2019_00 6     9     13     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:52
# Ntsr1Cre_2019_00 6     9     14     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:04
# Ntsr1Cre_2019_00 6     9     14     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:55
# Ntsr1Cre_2019_00 6     9     15     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:06
# Ntsr1Cre_2019_00 6     9     15     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:56
# Ntsr1Cre_2019_00 6     9     17     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:09
# Ntsr1Cre_2019_00 6     9     17     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:59
# Ntsr1Cre_2019_00 6     9     18     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:12
# Ntsr1Cre_2019_00 6     9     18     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:02
# Ntsr1Cre_2019_00 6     9     19     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:15
# Ntsr1Cre_2019_00 6     9     19     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:05
# Ntsr1Cre_2019_00 6     9     20     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:17
# Ntsr1Cre_2019_00 6     9     20     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:08
# Ntsr1Cre_2019_00 6     9     21     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 21:20
# Ntsr1Cre_2019_00 6     9     21     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:11
# Ntsr1Cre_2019_00 3     7     5      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:14
# Ntsr1Cre_2019_00 3     7     5      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:43
# Ntsr1Cre_2019_00 3     7     6      7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:17
# Ntsr1Cre_2019_00 3     7     6      8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:46
# Ntsr1Cre_2019_00 3     7     11     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:20
# Ntsr1Cre_2019_00 3     7     11     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:49
# Ntsr1Cre_2019_00 3     7     14     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:23
# Ntsr1Cre_2019_00 3     7     14     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:52
# Ntsr1Cre_2019_00 3     7     17     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:24
# Ntsr1Cre_2019_00 3     7     17     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:55
# Ntsr1Cre_2019_00 3     7     18     7                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:27
# Ntsr1Cre_2019_00 3     7     18     8                672             =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     2021-01-28 22:58
#    ...
#  (Total: 312)

# %%
SplineLNP.Eval()
# Out:
# *m               *s    *e    *u     *spl_paramset    spl_r_train     spl_r_test_mean  spl_r_test spl_fev          spl_rf_qi     spl_rf_thresh    spl_rf_area     spl_rf_pos spl_rf_val
# +--------------+ +---+ +---+ +----+ +--------------+ +-------------+ +--------------+ +--------+ +--------------+ +-----------+ +--------------+ +-------------+ +--------+ +------------+
# Ntsr1Cre_2019_00 6     9     1      7                0.0924886       0.0209005        =BLOB=     -0.0515001       0.332883      0.14             1.5             =BLOB=     0.209858
# Ntsr1Cre_2019_00 6     9     1      8                0.384698        0.337829         =BLOB=     8.74187          0.344007      0.22             1.0             =BLOB=     0.335369
# Ntsr1Cre_2019_00 6     9     3      7                0.0459176       0.00744719       =BLOB=     -0.0626533       0.582739      -0.19            1.75            =BLOB=     -0.45535
# Ntsr1Cre_2019_00 6     9     3      8                0.169721        0.208899         =BLOB=     1.34068          0.0749589     0.34             0.25            =BLOB=     0.367551
# Ntsr1Cre_2019_00 6     9     4      7                0.0170415       -0.0160711       =BLOB=     0.000303363      0.50608       0.12             2.75            =BLOB=     0.242954
# Ntsr1Cre_2019_00 6     9     4      8                0.0944799       0.058029         =BLOB=     0.0368549        0.18866       -0.15            0.75            =BLOB=     -0.184879
# Ntsr1Cre_2019_00 6     9     5      7                0.0189551       0.0187743        =BLOB=     -0.000956666     0.93824       -0.03            3.5             =BLOB=     -0.485748
# Ntsr1Cre_2019_00 6     9     5      8                0.0691038       0.0251705        =BLOB=     0.0326867        0.770879      -0.11            2.5             =BLOB=     -0.480096
# Ntsr1Cre_2019_00 6     9     7      7                0.114576        0.0990625        =BLOB=     0.0838462        0.661516      -0.08            6.75            =BLOB=     -0.236348
# Ntsr1Cre_2019_00 6     9     7      8                0.315362        0.278282         =BLOB=     1.20776          0.0394741     -0.27            0.25            =BLOB=     -0.281096
# Ntsr1Cre_2019_00 6     9     8      7                0.324028        0.345073         =BLOB=     0.62922          0.933401      0.02             13.5            =BLOB=     0.300306
# Ntsr1Cre_2019_00 6     9     8      8                0.559727        0.470184         =BLOB=     1.43702          0.939333      0.02             12.25           =BLOB=     0.329667
# Ntsr1Cre_2019_00 6     9     9      7                0.0773171       0.037512         =BLOB=     -2.2548          0.129795      -0.18            0.0             =BLOB=     -0.206848
# Ntsr1Cre_2019_00 6     9     9      8                0.373165        0.247964         =BLOB=     16.1277          0.461065      0.21             1.0             =BLOB=     0.389657
# Ntsr1Cre_2019_00 6     9     10     7                0.0567596       0.0395542        =BLOB=     -0.0457327       0.12622       0.23             0.75            =BLOB=     0.263224
# Ntsr1Cre_2019_00 6     9     10     8                0.165055        0.0431432        =BLOB=     0.679403         0.0331491     0.31             0.25            =BLOB=     0.320629
# Ntsr1Cre_2019_00 6     9     11     7                0.24254         0.221796         =BLOB=     0.381113         0.677658      0.1              4.75            =BLOB=     0.31023
# Ntsr1Cre_2019_00 6     9     11     8                0.439851        0.341207         =BLOB=     1.52844          0.909744      0.03             7.75            =BLOB=     0.332387
# Ntsr1Cre_2019_00 6     9     12     7                0.0964308       0.186993         =BLOB=     0.0775027        0.435019      0.11             6.0             =BLOB=     0.194697
# Ntsr1Cre_2019_00 6     9     12     8                0.459348        0.423416         =BLOB=     1.42489          0.591805      0.13             4.0             =BLOB=     0.318475
# Ntsr1Cre_2019_00 6     9     13     7                0.093467        0.08705          =BLOB=     -0.394743        0.493246      -0.13            2.0             =BLOB=     -0.256535
# Ntsr1Cre_2019_00 6     9     13     8                0.344763        0.206149         =BLOB=     4.74064          0.716756      0.07             2.75            =BLOB=     0.247137
# Ntsr1Cre_2019_00 6     9     14     7                0.143467        0.10615          =BLOB=     -0.486272        0.152472      -0.16            1.0             =BLOB=     -0.188784
# Ntsr1Cre_2019_00 6     9     14     8                0.479706        0.344602         =BLOB=     9.16254          0.962687      -0.01            18.0            =BLOB=     -0.268004
# Ntsr1Cre_2019_00 6     9     15     7                0.127015        0.0899144        =BLOB=     -5.65292         0.130989      0.18             0.5             =BLOB=     0.207132
# Ntsr1Cre_2019_00 6     9     15     8                0.381056        0.0925887        =BLOB=     213.171          0.290384      0.16             1.25            =BLOB=     0.225474
# Ntsr1Cre_2019_00 6     9     17     7                0.0430118       0.0188919        =BLOB=     0.757202         0.177567      0.19             1.0             =BLOB=     0.231022
# Ntsr1Cre_2019_00 6     9     17     8                0.366122        0.254346         =BLOB=     -10.4904         0.496225      0.17             1.75            =BLOB=     0.337453
# Ntsr1Cre_2019_00 6     9     18     7                0.0706521       -0.0225178       =BLOB=     0.25178          0.396483      0.14             2.25            =BLOB=     0.231974
# Ntsr1Cre_2019_00 6     9     18     8                0.327003        0.155944         =BLOB=     -8.2666          0.851783      -0.05            3.0             =BLOB=     -0.337344
# Ntsr1Cre_2019_00 6     9     20     7                0.0586005       0.0282985        =BLOB=     -0.28399         0.356076      0.14             1.5             =BLOB=     0.217417
# Ntsr1Cre_2019_00 6     9     20     8                0.2459          0.106019         =BLOB=     -44.3183         0.792824      -0.08            3.75            =BLOB=     -0.386146
# Ntsr1Cre_2019_00 6     9     21     7                0.0325581       0.0140541        =BLOB=     -0.4039          0.808859      -0.08            2.25            =BLOB=     -0.418539
# Ntsr1Cre_2019_00 6     9     21     8                0.136339        0.0978212        =BLOB=     3.07999          0.960183      -0.02            3.75            =BLOB=     -0.502296
# Ntsr1Cre_2019_00 3     7     5      7                0.0917598       0.0485986        =BLOB=     -0.0130077       0.119098      0.16             0.5             =BLOB=     0.181632
# Ntsr1Cre_2019_00 3     7     5      8                0.412407        0.384587         =BLOB=     1.18598          0.375793      0.16             3.0             =BLOB=     0.256325
# Ntsr1Cre_2019_00 3     7     6      7                0.0853258       0.0373156        =BLOB=     -0.0444946       0.102506      -0.18            0.25            =BLOB=     -0.200558
# Ntsr1Cre_2019_00 3     7     6      8                0.45355         0.457013         =BLOB=     1.86908          0.487677      -0.16            2.25            =BLOB=     -0.312303
# Ntsr1Cre_2019_00 3     7     14     7                0.146216        0.0814239        =BLOB=     0.0614496        0.682884      -0.13            2.25            =BLOB=     -0.409944
# Ntsr1Cre_2019_00 3     7     14     8                0.456605        0.421743         =BLOB=     2.02397          0.837924      -0.07            3.0             =BLOB=     -0.431895
# Ntsr1Cre_2019_00 3     7     17     7                0.0935139       0.0189581        =BLOB=     -0.0039568       0.541646      0.09             5.75            =BLOB=     0.196355
# Ntsr1Cre_2019_00 3     7     17     8                0.496093        0.450117         =BLOB=     1.96455          0.652083      0.11             2.0             =BLOB=     0.316168
# Ntsr1Cre_2019_00 3     7     18     7                0.115802        0.110516         =BLOB=     0.0256261        0.543607      -0.12            3.75            =BLOB=     -0.262931
# Ntsr1Cre_2019_00 3     7     18     8                0.376565        0.362836         =BLOB=     1.01868          0.943827      -0.02            10.75           =BLOB=     -0.356045
# Ntsr1Cre_2019_00 3     7     20     7                0.0898504       0.0417709        =BLOB=     -0.143009        0.384888      -0.11            3.0             =BLOB=     -0.178829
# Ntsr1Cre_2019_00 3     7     20     8                0.494475        0.440178         =BLOB=     3.90264          0.176768      -0.24            0.5             =BLOB=     -0.291534
# Ntsr1Cre_2019_00 3     7     22     7                0.128566        0.139269         =BLOB=     0.0640555        0.842428      -0.04            8.75            =BLOB=     -0.253852
# Ntsr1Cre_2019_00 3     7     22     8                0.562655        0.54057          =BLOB=     1.60417          0.949989      -0.02            8.5             =BLOB=     -0.399912
# Ntsr1Cre_2019_00 3     7     25     7                0.189745        0.205989         =BLOB=     0.240963         0.721814      0.09             4.75            =BLOB=     0.323525
# Ntsr1Cre_2019_00 3     7     25     8                0.396377        0.385192         =BLOB=     1.08028          0.887271      0.04             7.5             =BLOB=     0.354832
#    ...
#  (Total: 296)

# %%
Glm()
# Out:
# *m    *s    *e    *u    *glm_paramset    glm_b     glm_w_opt  glm_n_iter     glm_pred_t glm_pred_t glm_pred_t glm_ts
# +---+ +---+ +---+ +---+ +--------------+ +-------+ +--------+ +------------+ +--------+ +--------+ +--------+ +--------+
#
#  (Total: 0)

# %%
Glm.Eval()
# Out:
# *m    *s    *e    *u    *glm_paramset    glm_r_train     glm_r_test_mean  glm_r_test glm_fev     glm_rf_qi     glm_rf_thresh    glm_rf_area     glm_rf_pos glm_rf_val
# +---+ +---+ +---+ +---+ +--------------+ +-------------+ +--------------+ +--------+ +---------+ +-----------+ +--------------+ +-------------+ +--------+ +------------+
#
#  (Total: 0)

# %% [markdown]
# ## MODELLING MEMORY USAGE ANALYSIS
#
# BEFORE MODEL
# - SUMMARY: loading data ramps up mem usage for JNB from 800 MB (incl Python background vars) > 5.5 GB
#   - variable shapes and sizes in get_hmov_data()
#     - get_hmov_array() gets stimulus arrays:
#       - stimulus_train_exp_order: shape=(43200, 16, 25); 138 MB (float64); 30 Hz
#       - stimulus_test: shape=(1200, 16, 25); 3.84 MB (float64); 30 Hz
#     - upsample_movie() and train-validation-test split doubles array sizes by upsampling from 30 Hz > 60 Hz, i.e. 2-fold :
#       - stimulus_train: (64800, 16, 25); 207.36 MB (float64); 60 Hz
#       - stimulus_validation: (21600, 16, 25); 69.12 MB (float64); 60 Hz
#       - stimulus_test_interp: (2400, 16, 25); 7.68 MB (float64); 60 Hz
#     - build_design_matrix() multiplies by nlag=20, i.e. 20-fold:
#       - X_train: (64800, 8000)=(nsamples, w x h x lag)=(64800,16 x 25 x 20); 4.15 GB (float64)
#       - X_validation: (21600, 8000); 1.38 GB (float64)
#       - X_test: (2400, 8000); 0.15 GB (float64)
#     - memory usage of data variables before model initialization
#                X_train:  3.9 GiB
#           X_validation:  1.3 GiB
#                 X_test: 146.5 MiB
#                   pars:  1.2 KiB
#              parentkey:  376.0 B
#                hm_info:  376.0 B
#              responses:  376.0 B
#        splinelnp_entry:  376.0 B
#        validation_dict:  248.0 B
#         y_test_repeats:  200.0 B
#                   dims:   96.0 B
#         TOTAL USAGE INCL PYTHON BACKGROUND VARS: ca. 800 MB + 5.5 GB = 6.3 GB
#
# DURING MODEL
# - model initialization:
#   - increases mem usage from 5.5 GB > 12 GB, growing to 14.5 GB
#   - duration: 3:40 min
# - model filter initialization
#   - no mem increase
#   - duration: < 1 s
# - model fitting
#   - ramps up to 26 GB, with heavy use of swap memory: 5.6 GB -> thrashing (=rapid inefficient swapping between memory and storage)?
#     - at this peak of 26 GB, assuming data takes 5 GB, the model consumes 26 GB - 5 GB = 19 GB
#   - duration: 5 min
# - model prediction
#   - step reduces mem usage to 19 GB, then declining to 17 GB
#   - duration: 3 min
# => TOTAL PEAK MEM: ca. 25 GB (but depends heavily on model parameters, e.g. scaling=0.12 already crashes kernel)
# => TOTAL DURATION: ca. 12 min
#
# AFTER MODEL
# - at the end of the SplineLNP.make() function, mem usage is still 16 GB
#   - calling calling gc.collect() at this point does not change this
# - interrupting kernel immediately frees memory
#
# FOLLOWING make() RUN
#   - at the beginning of the following run of SplineLNP.make(), mem usage is still 16 GB
#     - to free up memory, calling gc.collect() at the start of SplineLNP.make() reduces memory from 16 GB > 6.5 GB
#       - so there seems to be a memory hangover of 6.6 GB - 800 MB = 5.2 GB (unclear if data or previous unclosed model)
#   - in the 2nd run of make(), after data loading, memory grows from 6.5 GB > 12 GB
#   - during model initialization, memory usage seems to be similar to the first run
#     - so the memory hangover seems to disappear at this point (presumably the previous model which was unclosed, gets overwritten)
#
# SUGGESTIONS FOR FREEING UP MEM SPACE
#   - we should try to reduce data type encoding to reduce the memory pressure
#     - uint8 instead of float64 can reduce memory by 8x
#       - but uint8 would not allow normalized values in range [0,1] > might need to resort to float32 or float16
#        - Encoding of 8-bit unsigned integers (0-255) as float16 should be fine, given that we can reconvert them into uint8 without loss of precision:
#          - (np.linspace(0,1,255).astype(np.float16) * 255).astype(np.uint8) = np.array([0,1,2,3....255])
#   - check any memory reduction techniques on the SplineLNPBehaviour package side
