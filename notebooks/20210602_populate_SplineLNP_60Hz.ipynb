# %% [markdown]
# # Connect to `dj_hmov`

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
run -im djd.main -- --dbname=dj_hmov
# Out:
# Connecting write@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'write@10.153.173.165'

# %% [markdown]
# # Check populated parameter sets

# %% [markdown]
# Should be `spl_paramset` 400-415:

# %%
SplineLNPParams()
# Out:
# *spl_paramset    spl_distr     spl_alpha     spl_lambda     spl_lr     spl_max_iter     spl_spat_df     spl_temp_df     spl_pshf     spl_pshf_len     spl_pshf_df     spl_verb     spl_metric     spl_norm_y     spl_nlag     spl_shift     spl_spat_scaling spl_data_fs     spl_opto     spl_opto_len     spl_opto_df     spl_run     spl_run_len     spl_run_df     spl_eye     spl_eye_len     spl_eye_df     spl_eye_smooth
# +--------------+ +-----------+ +-----------+ +------------+ +--------+ +--------------+ +-------------+ +-------------+ +----------+ +--------------+ +-------------+ +----------+ +------------+ +------------+ +----------+ +-----------+ +--------------+ +-------------+ +----------+ +--------------+ +-------------+ +---------+ +-------------+ +------------+ +---------+ +-------------+ +------------+ +--------------+
# ...

# %% [markdown]
# # Check `HmovUnit()` table

# %% [markdown]
# Should have around 150 units populated:

# %%
keys = HmovUnit.fetch(dj.key)
len(keys)
# Out:
# 159

# %% [markdown]
# # Populate `SplineLNP()` model table

# %%
SplineLNP().populate(reserve_jobs=True)
# Out:
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 401}
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 402}
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 403}
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# ...

# %%
SplineLNP().populate(reserve_jobs=True)
# Out:
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 401}
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 402}
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# SplineLNP() parentkey: {'m': 'Ntsr1Cre_2019_0007', 's': 6, 'e': 9, 'u': 16, 'spl_paramset': 403}
# Iters	  Time (s)	Cost (train)	Cost (dev)	Metric (train)	Metric (dev)
# Ntsr1Cre_2019_0007 s06 e09 u16 skipped due to :
# 	 invalid value encountered in true_divide
# ...
