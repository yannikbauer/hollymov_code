# %% [markdown]
# # run_get_all_unitexp_info:
# Convenience JNB to show how to use and to test get_all_unitexp_info()

# %% [markdown]
# ## TODO

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Start DJD
# Run main.py as interactive (-i) module (-m) and remotely (-r)\
# NOTE: any code inside the DJD-executing cell other than the executing line is not allowed

# %%
run -im djd.main -- --dbname=dj_hmov --user=write
# Out:
# Connecting write@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'write@10.153.173.165'

# %%
# Import standard libraries/modules
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import rcParams
import matplotlib.gridspec as gridspec
# %matplotlib inline

# Import custom modules
# NOTE: os.path.dirname(__file__) = '/Users/Yannik/code/djd/djd'
from djd import util, signal, plot # DJD modules
from .plot import plot_opto_titration

from l6s import l6s_utils
# Out:
# Importing l6s package.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Test unit info functions

# %%
unit_info_df = l6s_utils.get_all_unitexp_info(load_df_name='default')
unit_info_df
# Out:
# get_all_unitexp_info(): Getting combined unit info.
# ================================================================================
#   Loading saved unit info file: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/units_info_20210204.csv
#                        m  s   e    u s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  ...   fr_opto fr_opto_sem fr_spon_ctrl fr_spon_ctrl_sem fr_spon_opto  fr_spon_opto_sem  \
# 0     Ntsr1Cre_2019_0002  3   1   13      LGN    AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...       NaN         NaN          NaN              NaN          NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14      LGN    AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...       NaN         NaN          NaN              NaN          NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19      LGN    AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...       NaN         NaN          NaN              NaN          NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30      LGN    AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...       NaN         NaN          NaN              NaN          NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40      LGN    AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...       NaN         NaN          NaN              NaN          NaN               NaN
# ...                  ... ..  ..  ...      ...                    ...       ...       ...       ...       ...  ...       ...         ...          ...              ...          ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN       NaN  ...  0.002993         NaN          NaN              NaN          NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN       NaN  ...  2.674780         NaN          NaN              NaN          NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN       NaN  ...  8.350580         NaN          NaN              NaN          NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN       NaN  ...  3.041930         NaN          NaN              NaN          NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN       NaN  ...  9.960840         NaN          NaN              NaN          NaN               NaN
#
#       omi_stim omi_spon  snr_opto  snr_ctrl
# 0          NaN      NaN       NaN       NaN
# 1          NaN      NaN       NaN       NaN
# 2          NaN      NaN       NaN       NaN
# 3          NaN      NaN       NaN       NaN
# 4          NaN      NaN       NaN       NaN
# ...        ...      ...       ...       ...
# 2676 -0.992899      NaN       NaN       NaN
# 2677 -0.032479      NaN       NaN       NaN
# 2678  0.182203      NaN       NaN       NaN
# 2679 -0.000982      NaN       NaN       NaN
# 2680  0.005893      NaN       NaN       NaN
#
# [2681 rows x 35 columns]

# %%
df = unit_info_df.copy()
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & ((df.e_name.str.contains('SparseNoise')) | (df.e_name.str.contains('chirp')) | (df.e_name.str.contains('oriTun')) | (df.e_name.str.contains('conTun')))]
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & ((df.e_name.str.contains('SparseNoise')) | (df.e_name.str.contains('oriTun12')))]
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & (df.e_name.str.contains('oriTun8') | df.e_name.str.contains('oriTun12') | df.e_name.str.contains('chirp'))]
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & (df.e_name.str.contains('oriTun8'))]
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & (df.e_name.str.contains('Sparse'))]
# df = df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3)]
df = df[(df.m=='Ntsr1Cre_2020_0002') & (df.s==3)]
df
# Out:
#                        m  s   e   u s_region                                             e_name  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  ...  fr_opto fr_opto_sem fr_spon_ctrl fr_spon_ctrl_sem  \
# 1508  Ntsr1Cre_2020_0002  3   1   1      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1509  Ntsr1Cre_2020_0002  3   1   3      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1510  Ntsr1Cre_2020_0002  3   1   4      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1511  Ntsr1Cre_2020_0002  3   1  15      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1512  Ntsr1Cre_2020_0002  3   1  16      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# ...                  ... ..  ..  ..      ...                                                ...       ...       ...       ...       ...  ...      ...         ...          ...              ...
# 1671  Ntsr1Cre_2020_0002  3  13  41      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1672  Ntsr1Cre_2020_0002  3  13  43      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1673  Ntsr1Cre_2020_0002  3  13  46      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1674  Ntsr1Cre_2020_0002  3  13  47      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
# 1675  Ntsr1Cre_2020_0002  3  13  53      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN       NaN  ...      NaN         NaN          NaN              NaN
#
#      fr_spon_opto  fr_spon_opto_sem  omi_stim omi_spon  snr_opto  snr_ctrl
# 1508          NaN               NaN       NaN      NaN       NaN       NaN
# 1509          NaN               NaN       NaN      NaN       NaN       NaN
# 1510          NaN               NaN       NaN      NaN       NaN       NaN
# 1511          NaN               NaN       NaN      NaN       NaN       NaN
# 1512          NaN               NaN       NaN      NaN       NaN       NaN
# ...           ...               ...       ...      ...       ...       ...
# 1671          NaN               NaN       NaN      NaN       NaN       NaN
# 1672          NaN               NaN       NaN      NaN       NaN       NaN
# 1673          NaN               NaN       NaN      NaN       NaN       NaN
# 1674          NaN               NaN       NaN      NaN       NaN       NaN
# 1675          NaN               NaN       NaN      NaN       NaN       NaN
#
# [168 rows x 35 columns]

# %%
df2 = df[['m','s','e','u']]#, 'e_name', 's_region']]
df2
# Out:
#                        m  s   e   u
# 1508  Ntsr1Cre_2020_0002  3   1   1
# 1509  Ntsr1Cre_2020_0002  3   1   3
# 1510  Ntsr1Cre_2020_0002  3   1   4
# 1511  Ntsr1Cre_2020_0002  3   1  15
# 1512  Ntsr1Cre_2020_0002  3   1  16
# ...                  ... ..  ..  ..
# 1671  Ntsr1Cre_2020_0002  3  13  41
# 1672  Ntsr1Cre_2020_0002  3  13  43
# 1673  Ntsr1Cre_2020_0002  3  13  46
# 1674  Ntsr1Cre_2020_0002  3  13  47
# 1675  Ntsr1Cre_2020_0002  3  13  53
#
# [168 rows x 4 columns]

# %%
df3 = l6s_utils.get_unitexp_fr(df2, load_df_name=False)
df3
# Out:
# get_unitexp_fr(): Getting unit firing rates.
#   Excluded stimuli: OrientationContrFlashStim
#   Input parameter load_df_name = False. Fetching new firing rates.
#                       m  s   e   u  fr_mean_e  fr_sem_e  fr_mean_stim  fr_sem_stim  fr_mean_spon  fr_sem_spon  ...  fr_mean_opto  fr_sem_opto  fr_mean_stim_ctrl  fr_sem_stim_ctrl  fr_mean_stim_opto  \
# 0    Ntsr1Cre_2020_0002  3   1   1   2.063567  0.053789      2.063567     0.053789           NaN          NaN  ...           NaN          NaN                NaN               NaN                NaN
# 1    Ntsr1Cre_2020_0002  3   1   3  11.648162  0.223710     11.648162     0.223710           NaN          NaN  ...           NaN          NaN                NaN               NaN                NaN
# 2    Ntsr1Cre_2020_0002  3   1   4  17.194894  0.292756     17.194894     0.292756           NaN          NaN  ...           NaN          NaN                NaN               NaN                NaN
# 3    Ntsr1Cre_2020_0002  3   1  15   8.353937  0.302096      8.353937     0.302096           NaN          NaN  ...           NaN          NaN                NaN               NaN                NaN
# 4    Ntsr1Cre_2020_0002  3   1  16   0.733209  0.036966      0.733209     0.036966           NaN          NaN  ...           NaN          NaN                NaN               NaN                NaN
# ..                  ... ..  ..  ..        ...       ...           ...          ...           ...          ...  ...           ...          ...                ...               ...                ...
# 163  Ntsr1Cre_2020_0002  3  13  41   7.997380  0.490935      7.997380     0.490935           NaN          NaN  ...           NaN          NaN           7.997380          0.490935                NaN
# 164  Ntsr1Cre_2020_0002  3  13  43  13.599258  0.346813     13.599258     0.346813           NaN          NaN  ...           NaN          NaN          13.599258          0.346813                NaN
# 165  Ntsr1Cre_2020_0002  3  13  46   2.898680  0.113014      2.898680     0.113014           NaN          NaN  ...           NaN          NaN           2.898680          0.113014                NaN
# 166  Ntsr1Cre_2020_0002  3  13  47  14.726283  0.279731     14.726283     0.279731           NaN          NaN  ...           NaN          NaN          14.726283          0.279731                NaN
# 167  Ntsr1Cre_2020_0002  3  13  53   0.286959  0.049953      0.286959     0.049953           NaN          NaN  ...           NaN          NaN           0.286959          0.049953                NaN
#
#      fr_sem_stim_opto  fr_mean_spon_ctrl  fr_sem_spon_ctrl  fr_mean_spon_opto  fr_sem_spon_opto
# 0                 NaN                NaN               NaN                NaN               NaN
# 1                 NaN                NaN               NaN                NaN               NaN
# 2                 NaN                NaN               NaN                NaN               NaN
# 3                 NaN                NaN               NaN                NaN               NaN
# 4                 NaN                NaN               NaN                NaN               NaN
# ..                ...                ...               ...                ...               ...
# 163               NaN                NaN               NaN                NaN               NaN
# 164               NaN                NaN               NaN                NaN               NaN
# 165               NaN                NaN               NaN                NaN               NaN
# 166               NaN                NaN               NaN                NaN               NaN
# 167               NaN                NaN               NaN                NaN               NaN
#
# [168 rows x 22 columns]

# %%
df3.columns
# Out:
# Index(['m', 's', 'e', 'u', 'fr_mean_e', 'fr_sem_e', 'fr_mean_stim', 'fr_sem_stim', 'fr_mean_spon', 'fr_sem_spon', 'fr_mean_ctrl', 'fr_sem_ctrl', 'fr_mean_opto', 'fr_sem_opto', 'fr_mean_stim_ctrl',
#        'fr_sem_stim_ctrl', 'fr_mean_stim_opto', 'fr_sem_stim_opto', 'fr_mean_spon_ctrl', 'fr_sem_spon_ctrl', 'fr_mean_spon_opto', 'fr_sem_spon_opto'],
#       dtype='object')

# %%
df3 = l6s_utils.get_all_unitexp_info(mseu_df=df2)
df3
# Out:
# get_all_unitexp_info(): Getting combined unit experiment info.
# ================================================================================
# Start date and time: 05/21/2021, 19:47:51
#
# get_basic_mseu_info(): Adding info to mseu df: ['e_name', 's_region', 'm_genotype']
#
# get_unitexp_type(): Getting combined unit cell typing info.
#   Type info implemented: OSI/DSI, SbC, wave shape type, chirp response type
# --------------------------------------------------------
# get_unitexp_osi_dsi(): Getting unit orientation and direction selectivity index.
#   Stimuli implemented: ori
# get_unitexp_sbc(): Getting unit cell typing as suppressed by contrast.
#   Stimuli implemented: ori, con
# get_unitexp_chirp_type(): Getting chirp unit classification.
#   Loading previous ntsr1 chirp unit cluster types: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/chirp/chirp_cell_typing/data/units_ntsr1_chirp_type_20201102.csv
# get_unit_wave_type(): Getting unit wave type.
# get_units(): Getting units:
#   Mouse restrictions:		 m_strain LIKE "Ntsr1-Cre" AND m_notes LIKE "%stGtACR2%"
#   Series restrictions:		 s_region LIKE "V1"
#   Experiment restrictions:	 None
# get_units(): Getting units:
#   Mouse restrictions:		 m_strain LIKE "Ntsr1-Cre" AND m_notes LIKE "%stGtACR2%"
#   Series restrictions:		 s_region LIKE "LGN"
#   Experiment restrictions:	 None
#
# get_unitexp_state(): Getting unit state info.
# ------------------------------------------
# get_unitexp_burst_ratios(): Getting unit burst ratios.
#
# get_unitexp_crit(): Getting unit response quality criteria/indices.
# ----------------------------------------------------------------
# get_unitexp_tun_rsq: Getting tuning fit r-squared values.
#   Stimuli implemented: orientation, contrast, sparse noise
# get_unitexp_zscores(): Getting unit z-scores.
# get_unitexp_fr(): Getting unit firing rates.
#   Excluded stimuli: OrientationContrFlashStim
# Would you like to load previously fetched firing rate measures? (Otherwise, compute time can be ca. 5-50 min.)
# [yes, no]
# >>  no
#   Fetching new firing rates.
# get_unitexp_omi(): Getting unit opto-modulation index.
# get_unitexp_snr(): Getting unit signal-to-noise ratios.
#   Stimuli implemented: chirp
# ..............
# Stop date and time: 05/21/2021, 19:48:14
# -> Duration: 0:00:22.534285
# ================================================================================
#                       m  s   e   u m_genotype s_region                                             e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl  \
# 0    Ntsr1Cre_2020_0002  3   1   1        +/-      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 1    Ntsr1Cre_2020_0002  3   1   3        +/-      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 2    Ntsr1Cre_2020_0002  3   1   4        +/-      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 3    Ntsr1Cre_2020_0002  3   1  15        +/-      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 4    Ntsr1Cre_2020_0002  3   1  16        +/-      LGN                                AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN
# ..                  ... ..  ..  ..        ...      ...                                                ...       ...       ...       ...  ...               ...                ...              ...
# 163  Ntsr1Cre_2020_0002  3  13  41        +/-      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 164  Ntsr1Cre_2020_0002  3  13  43        +/-      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 165  Ntsr1Cre_2020_0002  3  13  46        +/-      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 166  Ntsr1Cre_2020_0002  3  13  47        +/-      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN  ...               NaN                NaN              NaN
# 167  Ntsr1Cre_2020_0002  3  13  53        +/-      LGN  titrate_light_intensity_doricLED_465nm_500mum_...       NaN       NaN       NaN  ...               NaN                NaN              NaN
#
#     fr_mean_spon_opto fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN              NaN   NaN       NaN       NaN      NaN       NaN
# ..                ...              ...   ...       ...       ...      ...       ...
# 163               NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 164               NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 165               NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 166               NaN              NaN   NaN       NaN       NaN      NaN       NaN
# 167               NaN              NaN   NaN       NaN       NaN      NaN       NaN
#
# [168 rows x 45 columns]

# %% [markdown]
# ## Run get_all_unitexp_info()
# check get_psth() and include splitbytrial kwarg option

# %%
mseu_df = l6s_utils.get_all_unitexp_info(load_fr_df=False, save_df_name='default')
mseu_df
# Out:
# get_all_unitexp_info(): Getting combined unit experiment info.
# ================================================================================
# Start date and time: 07/05/2021, 16:21:54
#
# get_mseu_df(): Getting dataframe of mseu keys.
# get_units(): Getting units:
#   Mouse restrictions:		 m_strain LIKE "Ntsr1-Cre" AND m_notes LIKE "%stGtACR2%"
#   Series restrictions:		 None
#   Experiment restrictions:	 None
#   Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/units_keys_20210705.csv
#   Saving mseu df meta data file: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/units_keys_20210705_meta.json
# get_basic_mseu_info(): Adding info to mseu df: ['e_name', 's_region', 'm_genotype']
#
# get_unitexp_type(): Getting combined unit cell typing info.
#   Type info implemented: OSI/DSI, SbC, wave shape type, chirp response type
# --------------------------------------------------------
# get_unitexp_osi_dsi(): Getting unit orientation and direction selectivity index.
#   Stimuli implemented: ori
# get_unitexp_sbc(): Getting unit cell typing as suppressed by contrast.
#   Stimuli implemented: ori, con
# get_unitexp_chirp_type(): Getting chirp unit classification.
#   Loading previous ntsr1 chirp unit cluster types: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/chirp/chirp_cell_typing/data/units_ntsr1_chirp_type_20201102.csv
# get_unit_wave_type(): Getting unit wave type.
#
# get_unitexp_state(): Getting unit state info.
# ------------------------------------------
# get_unitexp_burst_ratios(): Getting unit burst ratios.
#
# get_unitexp_crit(): Getting unit response quality criteria/indices.
# ----------------------------------------------------------------
# get_unitexp_tun_rsq: Getting tuning fit r-squared values.
#   Stimuli implemented: orientation, contrast, sparse noise
# get_unitexp_zscores(): Getting unit z-scores.
# get_unitexp_fr(): Getting unit firing rates.
#   Excluded stimuli: OrientationContrFlashStim
#   Input parameter load_df_name = False. Fetching new firing rates.
#   Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_fr_20210705.csv
# get_unitexp_omi(): Getting unit opto-modulation index.
# get_unitexp_snr(): Getting unit signal-to-noise ratios.
#   Stimuli implemented: chirp
# .............x...................................................x.............................................................................................................................................................................................................................
# Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210705.csv
#
# Saving mseu df meta data file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210705_meta.json
#
# Stop date and time: 07/05/2021, 16:32:37
# -> Duration: 0:10:43.430065
# ================================================================================
#                        m  s   e   u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1  13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1  14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1  19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1  30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1  40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ..        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 3123  Ntsr1Cre_2020_0004  6  14  58        +/-      LGN  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3124  Ntsr1Cre_2020_0004  6  14  61        +/-      LGN  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3125  Ntsr1Cre_2020_0004  6  14  66        +/-      LGN  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3126  Ntsr1Cre_2020_0004  6  14  68        +/-      LGN  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3127  Ntsr1Cre_2020_0004  6  14  70        +/-      LGN  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 3123              NaN   NaN       NaN       NaN      NaN       NaN
# 3124              NaN   NaN       NaN       NaN      NaN       NaN
# 3125              NaN   NaN       NaN       NaN      NaN       NaN
# 3126              NaN   NaN       NaN       NaN      NaN       NaN
# 3127              NaN   NaN       NaN       NaN      NaN       NaN
#
# [3128 rows x 45 columns]

# %%
mseu_df = l6s_utils.get_all_unitexp_info(load_fr_df=False, save_df_name='default')
mseu_df
# Out:
# get_all_unitexp_info(): Getting combined unit experiment info.
# ================================================================================
# Start date and time: 05/21/2021, 20:54:26
#
# get_mseu_df(): Getting dataframe of mseu keys.
# get_units(): Getting units:
#   Mouse restrictions:		 m_strain LIKE "Ntsr1-Cre" AND m_notes LIKE "%stGtACR2%"
#   Series restrictions:		 None
#   Experiment restrictions:	 None
#   Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/units_keys_20210521.csv
#   Saving mseu df meta data file: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/units_keys_20210521_meta.json
# get_basic_mseu_info(): Adding info to mseu df: ['e_name', 's_region', 'm_genotype']
#
# get_unitexp_type(): Getting combined unit cell typing info.
#   Type info implemented: OSI/DSI, SbC, wave shape type, chirp response type
# --------------------------------------------------------
# get_unitexp_osi_dsi(): Getting unit orientation and direction selectivity index.
#   Stimuli implemented: ori
# get_unitexp_sbc(): Getting unit cell typing as suppressed by contrast.
#   Stimuli implemented: ori, con
# get_unitexp_chirp_type(): Getting chirp unit classification.
#   Loading previous ntsr1 chirp unit cluster types: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/chirp/chirp_cell_typing/data/units_ntsr1_chirp_type_20201102.csv
# get_unit_wave_type(): Getting unit wave type.
#
# get_unitexp_state(): Getting unit state info.
# ------------------------------------------
# get_unitexp_burst_ratios(): Getting unit burst ratios.
#
# get_unitexp_crit(): Getting unit response quality criteria/indices.
# ----------------------------------------------------------------
# get_unitexp_tun_rsq: Getting tuning fit r-squared values.
#   Stimuli implemented: orientation, contrast, sparse noise
# get_unitexp_zscores(): Getting unit z-scores.
# get_unitexp_fr(): Getting unit firing rates.
#   Excluded stimuli: OrientationContrFlashStim
#   Input parameter load_df_name = False. Fetching new firing rates.
#   Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_fr_20210521.csv
# get_unitexp_omi(): Getting unit opto-modulation index.
# get_unitexp_snr(): Getting unit signal-to-noise ratios.
#   Stimuli implemented: chirp
# .............x...................................................x.............................................................................................................................................................................................
# Saving mseu df file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210521.csv
#
# Saving mseu df meta data file:		 /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210521_meta.json
#
# Stop date and time: 05/21/2021, 21:06:01
# -> Duration: 0:11:34.882728
# ================================================================================
#                        m  s   e    u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1   13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ...        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 2676              NaN   NaN       NaN       NaN      NaN       NaN
# 2677              NaN   NaN       NaN       NaN      NaN       NaN
# 2678              NaN   NaN       NaN       NaN      NaN       NaN
# 2679              NaN   NaN       NaN       NaN      NaN       NaN
# 2680              NaN   NaN       NaN       NaN      NaN       NaN
#
# [2681 rows x 45 columns]
