# %% [markdown]
# # Test rmv_dupl_unitexps() on unit info df

# %%
run -im djd.main -- --dbname=dj_hmov --user=write
# Out:
# Connecting write@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'write@10.153.173.165'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from djd import hmov_models
from djd import hmov_unit
from l6s import l6s_utils # Layer 6 suppression code repo with utility functions for plotting unit overview
# Out:
# Importing l6s package.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Get unit info df
unit_info = l6s_utils.get_all_unitexp_info(load_df_name='unitexp_info_20210521')
unit_info
# Out:
# get_all_unitexp_info(): Getting combined unit experiment info.
# ================================================================================
#   Loading saved unit info file: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210521.csv
#                        m  s   e    u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1   13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ...        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 2676              NaN   NaN       NaN       NaN      NaN       NaN
# 2677              NaN   NaN       NaN       NaN      NaN       NaN
# 2678              NaN   NaN       NaN       NaN      NaN       NaN
# 2679              NaN   NaN       NaN       NaN      NaN       NaN
# 2680              NaN   NaN       NaN       NaN      NaN       NaN
#
# [2681 rows x 45 columns]

# %%
ukey = {'m': 'Ntsr1Cre_2020_0001', 's':3}#, 'e_name': 'conTun12_opto'}
df = unit_info.loc[np.all(unit_info[list(ukey)] == pd.Series(ukey), axis=1)]
df = df[['m','s','e','u','e_name','tun_rsq_ctrl', 'tun_rsq_opto', 'OSI_ctrl', 'OSI_opto', 'sbc_zscore', 'OMI']]
df['tun_rsq_ctrl'].loc[1149] = np.nan # set to nan for testing
df['tun_rsq_ctrl'].loc[1263] = np.nan # set to nan for testing
print(len(df))
df
# Out:
# 228
# /Users/ybauer/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                        m  s   e   u               e_name  tun_rsq_ctrl  tun_rsq_opto  OSI_ctrl  OSI_opto  sbc_zscore       OMI
# 1073  Ntsr1Cre_2020_0001  3   1   3  AsparseNoise5_60deg      0.689228           NaN       NaN       NaN         NaN -0.023089
# 1074  Ntsr1Cre_2020_0001  3   1   7  AsparseNoise5_60deg      0.523548           NaN       NaN       NaN         NaN -0.016644
# 1075  Ntsr1Cre_2020_0001  3   1  10  AsparseNoise5_60deg      0.109300           NaN       NaN       NaN         NaN -0.009049
# 1076  Ntsr1Cre_2020_0001  3   1  13  AsparseNoise5_60deg      0.524570           NaN       NaN       NaN         NaN -0.006022
# 1077  Ntsr1Cre_2020_0001  3   1  14  AsparseNoise5_60deg      0.155310           NaN       NaN       NaN         NaN  0.000000
# ...                  ... ..  ..  ..                  ...           ...           ...       ...       ...         ...       ...
# 1296  Ntsr1Cre_2020_0001  3  13  42  AsparseNoise5_60deg      0.717451           NaN       NaN       NaN         NaN  0.103822
# 1297  Ntsr1Cre_2020_0001  3  13  50  AsparseNoise5_60deg      0.168636           NaN       NaN       NaN         NaN  0.006762
# 1298  Ntsr1Cre_2020_0001  3  13  51  AsparseNoise5_60deg      0.144260           NaN       NaN       NaN         NaN -0.081821
# 1299  Ntsr1Cre_2020_0001  3  13  53  AsparseNoise5_60deg      0.047000           NaN       NaN       NaN         NaN  0.021703
# 1300  Ntsr1Cre_2020_0001  3  13  59  AsparseNoise5_60deg      0.038754           NaN       NaN       NaN         NaN -0.016059
#
# [228 rows x 11 columns]

# %%
l6s_utils.rmv_dupl_unitexps(unit_info)
# Out:
# rmv_dupl_unitexps(): Criteria for duplicate unit experiment removal: {'oriTun12': 'tun_rsq_ctrl', 'oriTun8': 'tun_rsq_ctrl', 'conTun12_opto': 'tun_rsq_ctrl', 'conTun_opto': 'tun_rsq_ctrl', 'chirp': 'snr_ctrl'}
#   Removing 95 duplicate unit experiments (out of 347) for oriTun12: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 24) for oriTun8: tun_rsq_ctrl.
#   Removing 18 duplicate unit experiments (out of 187) for conTun12_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 8) for conTun_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 253) for chirp: snr_ctrl.
#   Removing total of 113 duplicates from input df of length 2681 (df may still include stimuli without duplicate removal criteria).
#                        m  s   e    u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1   13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ...        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 2676              NaN   NaN       NaN       NaN      NaN       NaN
# 2677              NaN   NaN       NaN       NaN      NaN       NaN
# 2678              NaN   NaN       NaN       NaN      NaN       NaN
# 2679              NaN   NaN       NaN       NaN      NaN       NaN
# 2680              NaN   NaN       NaN       NaN      NaN       NaN
#
# [2568 rows x 45 columns]

# %%
l6s_utils.rmv_dupl_unitexps(unit_info)
# Out:
# rmv_dupl_unitexps(): Criteria for duplicate unit experiment removal: {'oriTun12': 'tun_rsq_ctrl', 'oriTun8': 'tun_rsq_ctrl', 'conTun12_opto': 'tun_rsq_ctrl', 'conTun_opto': 'tun_rsq_ctrl', 'chirp': 'snr_ctrl'}
#   Removing 95 duplicate unit experiments (out of 347) for oriTun12: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 24) for oriTun8: tun_rsq_ctrl.
#   Removing 18 duplicate unit experiments (out of 187) for conTun12_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 8) for conTun_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 253) for chirp: snr_ctrl.
#   Removing total of 113 duplicates from input df of length 2681 (df may still include stimuli without duplicate removal criteria).
#                        m  s   e    u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1   13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ...        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 2676              NaN   NaN       NaN       NaN      NaN       NaN
# 2677              NaN   NaN       NaN       NaN      NaN       NaN
# 2678              NaN   NaN       NaN       NaN      NaN       NaN
# 2679              NaN   NaN       NaN       NaN      NaN       NaN
# 2680              NaN   NaN       NaN       NaN      NaN       NaN
#
# [2568 rows x 45 columns]
