# %% [markdown]
# # Test reduce_unitexp2unit_info()

# %%
run -im djd.main -- --dbname=dj_hmov --user=write
# Out:
# Connecting write@huxley.neuro.bzm:3306
# Connected to database 'dj_hmov' as 'write@10.153.173.165'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from djd import hmov_models
from djd import hmov_unit
from l6s import l6s_utils # Layer 6 suppression code repo with utility functions for plotting unit overview
# Out:
# Importing l6s package.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Get unit info df
df = l6s_utils.get_all_unitexp_info(load_df_name='unitexp_info_20210521')
df
# Out:
# get_all_unitexp_info(): Getting combined unit experiment info.
# ================================================================================
#   Loading saved unit info file: /Users/ybauer/GDrive/BBE_BusseBerensEuler/projects/ct-fb_L6_suppression/analyses/L6_suppression/l6s/unit_crit_and_type_info/data/unitexp_info_20210521.csv
#                        m  s   e    u m_genotype s_region                 e_name  osi_ctrl  osi_opto  dsi_ctrl  ...  fr_sem_stim_opto  fr_mean_spon_ctrl fr_sem_spon_ctrl fr_mean_spon_opto  \
# 0     Ntsr1Cre_2019_0002  3   1   13        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 1     Ntsr1Cre_2019_0002  3   1   14        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2     Ntsr1Cre_2019_0002  3   1   19        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 3     Ntsr1Cre_2019_0002  3   1   30        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 4     Ntsr1Cre_2019_0002  3   1   40        +/-      LGN    AsparseNoise5_60deg       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# ...                  ... ..  ..  ...        ...      ...                    ...       ...       ...       ...  ...               ...                ...              ...               ...
# 2676  Ntsr1Cre_2020_0003  2  17  140        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2677  Ntsr1Cre_2020_0003  2  17  141        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2678  Ntsr1Cre_2020_0003  2  17  142        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2679  Ntsr1Cre_2020_0003  2  17  144        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
# 2680  Ntsr1Cre_2020_0003  2  17  145        +/-       V1  MAS_1400_200-500_ChR2       NaN       NaN       NaN  ...               NaN                NaN              NaN               NaN
#
#      fr_sem_spon_opto omi_e  omi_stim  omi_spon snr_opto  snr_ctrl
# 0                 NaN   NaN       NaN       NaN      NaN       NaN
# 1                 NaN   NaN       NaN       NaN      NaN       NaN
# 2                 NaN   NaN       NaN       NaN      NaN       NaN
# 3                 NaN   NaN       NaN       NaN      NaN       NaN
# 4                 NaN   NaN       NaN       NaN      NaN       NaN
# ...               ...   ...       ...       ...      ...       ...
# 2676              NaN   NaN       NaN       NaN      NaN       NaN
# 2677              NaN   NaN       NaN       NaN      NaN       NaN
# 2678              NaN   NaN       NaN       NaN      NaN       NaN
# 2679              NaN   NaN       NaN       NaN      NaN       NaN
# 2680              NaN   NaN       NaN       NaN      NaN       NaN
#
# [2681 rows x 45 columns]

# %%
msudf = l6s_utils.reduce_unitexp2unit_info(df, apply_crit=True, default_crit=True, 
                                           manual_crit={'all': {'s_region': 'LGN',
#                                                                'm_genotype': '+/-',
                                                               }})
msudf
# Out:
# reduce_unitexp2unit_info(): Reducing unit-experiment df (n rows = 2681) to unit df.
# apply_unitexp_crit(): Applying unit selection criteria.
#   defaults: True; manuals: {'all': {'s_region': 'LGN'}}
# set_unitexp_crit(): Setting criteria:
#    {'all': {'fr_mean_e': 0.5, 's_region': 'LGN'}, 'oriTun': {'tun_rsq_ctrl': 0.25, 'fr_mean_e': 0.5}}
# apply_unitexp_crit():
#   256/2681 (9.55 %) unit exps did not pass criterion 0.5 applied to group: fr_mean_e.
#   779/2681 (29.06 %) unit exps did not pass criterion LGN applied to group: s_region.
#   1035/2681 (38.6 %) unit exps did not pass criterion {'fr_mean_e': 0.5, 's_region': 'LGN'} applied to group: all.
#   77/2681 (2.87 %) unit exps did not pass criterion {'tun_rsq_ctrl': 0.25, 'fr_mean_e': 0.5} applied to group: oriTun.
#   Removing total of 936 unique unit experiments from input df of length 2681 (34.91 %). 1745 (65.09 %) remaining.
# rmv_dupl_unitexps(): Criteria for duplicate unit experiment removal:
#   {'oriTun12': 'tun_rsq_ctrl', 'oriTun8': 'tun_rsq_ctrl', 'conTun12_opto': 'tun_rsq_ctrl', 'conTun_opto': 'tun_rsq_ctrl', 'chirp': 'snr_ctrl'}
#   Removing 31 duplicate unit experiments (out of 198) for oriTun12: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 19) for oriTun8: tun_rsq_ctrl.
#   Removing 16 duplicate unit experiments (out of 128) for conTun12_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 5) for conTun_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 179) for chirp: snr_ctrl.
#   Removing total of 47 duplicates from input df of length 1745 (df may still include stimuli without duplicate removal criteria). 1698 remaining.
# reduce_unitexp2unit_info(): Reduced 1698 remaining unit-experiments to 198 units.
#                       m  s   u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 0    Ntsr1Cre_2019_0002  3  13        +/-      LGN       ON-sust.  0.058347  0.015818  0.003239  0.081268    8.678365  False     excit
# 1    Ntsr1Cre_2019_0002  3  14        +/-      LGN  ON-OFF-trans.  0.019194  0.067131  0.093939  0.070952    4.316509  False     excit
# 2    Ntsr1Cre_2019_0002  3  19        +/-      LGN          mixed  0.132265  0.150986  0.242817  0.033709    0.068580  False     excit
# 3    Ntsr1Cre_2019_0002  3  30        +/-      LGN  ON-OFF-trans.  0.122563  0.020055  0.086487  0.127151    1.423739  False     excit
# 4    Ntsr1Cre_2019_0002  3  40        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN    2.780215  False     excit
# ..                  ... ..  ..        ...      ...            ...       ...       ...       ...       ...         ...    ...       ...
# 193  Ntsr1Cre_2020_0002  6  28        +/-      LGN      OFF-sust.  0.056904  0.016069  0.336862  0.102671    1.561458  False     excit
# 194  Ntsr1Cre_2020_0002  6  33        +/-      LGN            NaN  0.050882  0.061101  0.038114  0.001934    1.231234  False     excit
# 195  Ntsr1Cre_2020_0002  6  38        +/-      LGN            NaN  0.035581  0.079042  0.114845  0.040818    0.208226  False     excit
# 196  Ntsr1Cre_2020_0002  6  42        +/-      LGN            NaN  0.058159  0.055284  0.106481  0.035697    1.335863  False     excit
# 197  Ntsr1Cre_2020_0002  6  30        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
#
# [198 rows x 13 columns]

# %%
msudf = l6s_utils.reduce_unitexp2unit_info(df, apply_crit=True, default_crit=True, 
                                           manual_crit={'all': {'s_region': 'LGN',
                                                               'm_genotype': '+/-'}})
msudf
# Out:
# reduce_unitexp2unit_info(): Reducing unit-experiment df (n rows = 2681) to unit df.
# apply_unitexp_crit(): Applying unit selection criteria.
# 	defaults: True; manuals: {'all': {'s_region': 'LGN', 'm_genotype': '+/-'}}
# set_unitexp_crit(): Criteria: {'all': {'fr_mean_e': 0.5, 's_region': 'LGN', 'm_genotype': '+/-'}, 'oriTun': {'tun_rsq_ctrl': 0.25, 'fr_mean_e': 0.5}}
# 256/2681 (9.55 %) unit exps did not pass criterion 0.5 applied to group: fr_mean_e.
# 779/2681 (29.06 %) unit exps did not pass criterion LGN applied to group: s_region.
# 605/2681 (22.57 %) unit exps did not pass criterion +/- applied to group: m_genotype.
# 1640/2681 (61.17 %) unit exps did not pass criterion {'fr_mean_e': 0.5, 's_region': 'LGN', 'm_genotype': '+/-'} applied to group: all.
# 77/2681 (2.87 %) unit exps did not pass criterion {'tun_rsq_ctrl': 0.25, 'fr_mean_e': 0.5} applied to group: oriTun.
# Removing total of 1336 unique unit experiments from input df of length 2681 (49.83 %).
# rmv_dupl_unitexps(): Criteria for duplicate unit experiment removal: {'oriTun12': 'tun_rsq_ctrl', 'oriTun8': 'tun_rsq_ctrl', 'conTun12_opto': 'tun_rsq_ctrl', 'conTun_opto': 'tun_rsq_ctrl', 'chirp': 'snr_ctrl'}
#   Removing 15 duplicate unit experiments (out of 146) for oriTun12: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 19) for oriTun8: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 75) for conTun12_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 5) for conTun_opto: tun_rsq_ctrl.
#   Removing 0 duplicate unit experiments (out of 141) for chirp: snr_ctrl.
#   Removing total of 15 duplicates from input df of length 1345 (df may still include stimuli without duplicate removal criteria).
# reduce_unitexp2unit_info(): Reduced 1330 remaining unit-experiments to 157 units.
#                       m  s   u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 0    Ntsr1Cre_2019_0002  3  13        +/-      LGN       ON-sust.  0.058347  0.015818  0.003239  0.081268    8.678365  False     excit
# 1    Ntsr1Cre_2019_0002  3  14        +/-      LGN  ON-OFF-trans.  0.019194  0.067131  0.093939  0.070952    4.316509  False     excit
# 2    Ntsr1Cre_2019_0002  3  19        +/-      LGN          mixed  0.132265  0.150986  0.242817  0.033709    0.068580  False     excit
# 3    Ntsr1Cre_2019_0002  3  30        +/-      LGN  ON-OFF-trans.  0.122563  0.020055  0.086487  0.127151    1.423739  False     excit
# 4    Ntsr1Cre_2019_0002  3  40        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN    2.780215  False     excit
# ..                  ... ..  ..        ...      ...            ...       ...       ...       ...       ...         ...    ...       ...
# 152  Ntsr1Cre_2020_0002  6  28        +/-      LGN      OFF-sust.  0.056904  0.016069  0.336862  0.102671    1.561458  False     excit
# 153  Ntsr1Cre_2020_0002  6  33        +/-      LGN            NaN  0.050882  0.061101  0.038114  0.001934    1.231234  False     excit
# 154  Ntsr1Cre_2020_0002  6  38        +/-      LGN            NaN  0.035581  0.079042  0.114845  0.040818    0.208226  False     excit
# 155  Ntsr1Cre_2020_0002  6  42        +/-      LGN            NaN  0.058159  0.055284  0.106481  0.035697    1.335863  False     excit
# 156  Ntsr1Cre_2020_0002  6  30        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
#
# [157 rows x 13 columns]

# %%
msudf[msudf.s_region=='LGN']
# Out:
#                       m  s   u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 0    Ntsr1Cre_2019_0002  3  13        +/-      LGN       ON-sust.  0.058347  0.015818  0.003239  0.081268    8.678365  False     excit
# 1    Ntsr1Cre_2019_0002  3  14        +/-      LGN  ON-OFF-trans.  0.019194  0.067131  0.093939  0.070952    4.316509  False     excit
# 2    Ntsr1Cre_2019_0002  3  19        +/-      LGN          mixed  0.132265  0.150986  0.242817  0.033709    0.068580  False     excit
# 3    Ntsr1Cre_2019_0002  3  30        +/-      LGN  ON-OFF-trans.  0.122563  0.020055  0.086487  0.127151    1.423739  False     excit
# 4    Ntsr1Cre_2019_0002  3  40        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN    2.780215  False     excit
# ..                  ... ..  ..        ...      ...            ...       ...       ...       ...       ...         ...    ...       ...
# 152  Ntsr1Cre_2020_0002  6  28        +/-      LGN      OFF-sust.  0.056904  0.016069  0.336862  0.102671    1.561458  False     excit
# 153  Ntsr1Cre_2020_0002  6  33        +/-      LGN            NaN  0.050882  0.061101  0.038114  0.001934    1.231234  False     excit
# 154  Ntsr1Cre_2020_0002  6  38        +/-      LGN            NaN  0.035581  0.079042  0.114845  0.040818    0.208226  False     excit
# 155  Ntsr1Cre_2020_0002  6  42        +/-      LGN            NaN  0.058159  0.055284  0.106481  0.035697    1.335863  False     excit
# 156  Ntsr1Cre_2020_0002  6  30        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
#
# [157 rows x 13 columns]

# %%
msudf[msudf.m_genotype=='-/-']
# Out:
# Empty DataFrame
# Columns: [m, s, u, m_genotype, s_region, chirp_type, osi_ctrl, osi_opto, dsi_ctrl, dsi_opto, sbc_zscore, sbc, wave_type]
# Index: []

# %% [markdown]
# ## Check validity of df vs msudf info

# %%
# df[(df.m=='Ntsr1Cre_2019_0002') & (df.s==3) & (df.e_name.str.contains('conTun'))][['m','s','u', 'e', 'e_name', 'sbc_zscore', 'sbc']]
df[(df.m=='Ntsr1Cre_2019_0008') & (df.s==3) & (df.u==25)][['m','s','u', 'e', 'e_name', 'm_genotype', 's_region', 
                                                           'chirp_type', 'osi_ctrl', 'osi_opto', 'dsi_ctrl', 'dsi_opto',
                                                           'sbc_zscore', 'sbc', 'tun_rsq_ctrl', 'wave_type']]
# Out:
#                       m  s   u  e                 e_name m_genotype s_region chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc  tun_rsq_ctrl wave_type
# 622  Ntsr1Cre_2019_0008  3  25  1         AoriTun12_opto        +/-      LGN        NaN  0.034255  0.037651  0.137009  0.177672   -1.328349  False      0.428827     excit
# 636  Ntsr1Cre_2019_0008  3  25  2      Aspontaneous_opto        +/-      LGN        NaN       NaN       NaN       NaN       NaN         NaN    NaN           NaN     excit
# 650  Ntsr1Cre_2019_0008  3  25  3    ASparseNoise5_60deg        +/-      LGN        NaN       NaN       NaN       NaN       NaN         NaN    NaN      0.549848     excit
# 664  Ntsr1Cre_2019_0008  3  25  4  MAS_1400_200-500_ChR2        +/-      LGN        NaN       NaN       NaN       NaN       NaN         NaN    NaN           NaN     excit
# 678  Ntsr1Cre_2019_0008  3  25  5          AoriTun8_opto        +/-      LGN        NaN       NaN       NaN       NaN       NaN   -0.062017  False           NaN     excit
# 691  Ntsr1Cre_2019_0008  3  25  6             chirp_opto        +/-      LGN   ON-sust.       NaN       NaN       NaN       NaN         NaN    NaN           NaN     excit
# 704  Ntsr1Cre_2019_0008  3  25  7        hollymov_opto_3        +/-      LGN        NaN       NaN       NaN       NaN       NaN         NaN    NaN           NaN     excit

# %%
# df[(df.m=='Ntsr1Cre_2019_0002') & (df.s==3) & (df.e_name.str.contains('conTun'))][['m','s','u', 'e', 'e_name', 'sbc_zscore', 'sbc']]
msudf[(msudf.m=='Ntsr1Cre_2019_0002') & (msudf.s==3) & (msudf.u==13)][['m','s','u', 'm_genotype', 's_region', 
                                                           'chirp_type', 'osi_ctrl', 'osi_opto', 'dsi_ctrl', 'dsi_opto',
                                                           'sbc_zscore', 'sbc', 'wave_type']]
# Out:
#                     m  s   u m_genotype s_region chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 0  Ntsr1Cre_2019_0002  3  13        +/-      LGN   ON-sust.  0.058347  0.015818  0.003239  0.081268    8.678365  False     excit

# %%
msudf[msudf.m_genotype=='-/-']
# Out:
#                       m  s    u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 107  Ntsr1Cre_2020_0001  2    2        -/-       V1  ON-OFF-trans.       NaN       NaN       NaN       NaN    1.293716  False     inhib
# 108  Ntsr1Cre_2020_0001  2   21        -/-       V1            NaN  0.032603  0.107860  0.201830  0.140275    5.370272  False     inhib
# 109  Ntsr1Cre_2020_0001  2   58        -/-       V1          mixed  0.338553  0.328343  0.143333  0.202158   -7.206976   True     excit
# 110  Ntsr1Cre_2020_0001  2   99        -/-       V1       ON-sust.  0.083457  0.043642  0.096836  0.089671    6.098865  False     excit
# 111  Ntsr1Cre_2020_0001  2  150        -/-       V1       ON-sust.  0.149871  0.121352  0.044889  0.059329   -0.510505  False     inhib
# ..                  ... ..  ...        ...      ...            ...       ...       ...       ...       ...         ...    ...       ...
# 160  Ntsr1Cre_2020_0001  4   58        -/-      LGN          mixed  0.071683  0.057456  0.019159  0.015834   -0.618688  False     excit
# 161  Ntsr1Cre_2020_0001  4   26        -/-      LGN      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 162  Ntsr1Cre_2020_0001  4   29        -/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 163  Ntsr1Cre_2020_0001  4   40        -/-      LGN      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 164  Ntsr1Cre_2020_0001  4   53        -/-      LGN       ON-sust.       NaN       NaN       NaN       NaN   -0.098346  False     excit
#
# [58 rows x 13 columns]

# %%
msudf[msudf.s_region=='V1']
# Out:
#                       m  s    u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 107  Ntsr1Cre_2020_0001  2    2        -/-       V1  ON-OFF-trans.       NaN       NaN       NaN       NaN    1.293716  False     inhib
# 108  Ntsr1Cre_2020_0001  2   21        -/-       V1            NaN  0.032603  0.107860  0.201830  0.140275    5.370272  False     inhib
# 109  Ntsr1Cre_2020_0001  2   58        -/-       V1          mixed  0.338553  0.328343  0.143333  0.202158   -7.206976   True     excit
# 110  Ntsr1Cre_2020_0001  2   99        -/-       V1       ON-sust.  0.083457  0.043642  0.096836  0.089671    6.098865  False     excit
# 111  Ntsr1Cre_2020_0001  2  150        -/-       V1       ON-sust.  0.149871  0.121352  0.044889  0.059329   -0.510505  False     inhib
# ..                  ... ..  ...        ...      ...            ...       ...       ...       ...       ...         ...    ...       ...
# 258  Ntsr1Cre_2020_0003  2  116        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN       NaN
# 259  Ntsr1Cre_2020_0003  2  101        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 260  Ntsr1Cre_2020_0003  2   67        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 261  Ntsr1Cre_2020_0003  2   11        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 262  Ntsr1Cre_2020_0003  2   72        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
#
# [57 rows x 13 columns]

# %%
# df[(df.m=='Ntsr1Cre_2019_0002') & (df.s==3) & (df.e_name.str.contains('conTun'))][['m','s','u', 'e', 'e_name', 'sbc_zscore', 'sbc']]
df[(df.m=='Ntsr1Cre_2019_0002') & (df.s==3) & (df.u==40)][['m','s','u', 'e', 'e_name', 'm_genotype', 's_region', 
                                                           'chirp_type', 'osi_ctrl', 'osi_opto', 'dsi_ctrl', 'dsi_opto',
                                                           'sbc_zscore', 'sbc', 'wave_type']]
# Out:
#                      m  s   u   e                 e_name m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 4   Ntsr1Cre_2019_0002  3  40   1    AsparseNoise5_60deg        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 12  Ntsr1Cre_2019_0002  3  40   2      Aspontaneous_opto        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 20  Ntsr1Cre_2019_0002  3  40   3          oriTun12_opto        +/-      LGN            NaN  0.030719  0.052259  0.101183  0.115787    6.814885  False     excit
# 28  Ntsr1Cre_2019_0002  3  40   4          conTun12_opto        +/-      LGN            NaN       NaN       NaN       NaN       NaN    2.780215  False     excit
# 36  Ntsr1Cre_2019_0002  3  40   5        compoundOriSfTf        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 44  Ntsr1Cre_2019_0002  3  40   6             chirp_opto        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 52  Ntsr1Cre_2019_0002  3  40   7        compoundOriSfTf        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 60  Ntsr1Cre_2019_0002  3  40   8  MAS_1400_200-500_opto        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 68  Ntsr1Cre_2019_0002  3  40   9             tfTun_opto        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 76  Ntsr1Cre_2019_0002  3  40  10            conTun_opto        +/-      LGN            NaN       NaN       NaN       NaN       NaN   -0.382231  False     excit

# %%
msudf[np.isnan(msudf.osi_ctrl)]
# Out:
#                       m  s    u m_genotype s_region     chirp_type  osi_ctrl  osi_opto  dsi_ctrl  dsi_opto  sbc_zscore    sbc wave_type
# 4    Ntsr1Cre_2019_0002  3   40        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN    2.780215  False     excit
# 12   Ntsr1Cre_2019_0003  4    7        +/-      LGN            NaN       NaN       NaN       NaN       NaN   -0.030973  False     excit
# 19   Ntsr1Cre_2019_0003  4   14        +/-      LGN       ON-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 21   Ntsr1Cre_2019_0003  4    1        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 22   Ntsr1Cre_2019_0003  4   23        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 31   Ntsr1Cre_2019_0007  4   82        +/-      LGN          mixed       NaN       NaN       NaN       NaN   -1.488008  False     inhib
# 33   Ntsr1Cre_2019_0007  4   64        +/-      LGN          mixed       NaN       NaN       NaN       NaN    2.694759  False     inhib
# 35   Ntsr1Cre_2019_0007  4   52        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 37   Ntsr1Cre_2019_0007  5   38        +/-      NaN            NaN       NaN       NaN       NaN       NaN         NaN    NaN       NaN
# 42   Ntsr1Cre_2019_0007  5   43        +/-      NaN            NaN       NaN       NaN       NaN       NaN         NaN    NaN       NaN
# 47   Ntsr1Cre_2019_0007  6    6        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 56   Ntsr1Cre_2019_0007  6   19        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 59   Ntsr1Cre_2019_0007  6    2        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     inhib
# 60   Ntsr1Cre_2019_0007  6    5        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 76   Ntsr1Cre_2019_0008  3   17        +/-      LGN      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 77   Ntsr1Cre_2019_0008  3   20        +/-      LGN          mixed       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 78   Ntsr1Cre_2019_0008  3   30        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 95   Ntsr1Cre_2019_0008  7    3        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     inhib
# 99   Ntsr1Cre_2019_0008  7    7        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     inhib
# 100  Ntsr1Cre_2019_0008  7    8        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 101  Ntsr1Cre_2019_0008  7    9        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     inhib
# 102  Ntsr1Cre_2019_0008  7   10        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     inhib
# 107  Ntsr1Cre_2020_0001  2    2        -/-       V1  ON-OFF-trans.       NaN       NaN       NaN       NaN    1.293716  False     inhib
# 117  Ntsr1Cre_2020_0001  2    6        -/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 119  Ntsr1Cre_2020_0001  2   44        -/-       V1            NaN       NaN       NaN       NaN       NaN    1.976279  False     excit
# 121  Ntsr1Cre_2020_0001  2   19        -/-       V1      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN       NaN
# 122  Ntsr1Cre_2020_0001  2   38        -/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 123  Ntsr1Cre_2020_0001  2   54        -/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 147  Ntsr1Cre_2020_0001  4   17        -/-      LGN          mixed       NaN       NaN       NaN       NaN    5.906291  False     excit
# 161  Ntsr1Cre_2020_0001  4   26        -/-      LGN      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 162  Ntsr1Cre_2020_0001  4   29        -/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 163  Ntsr1Cre_2020_0001  4   40        -/-      LGN      OFF-sust.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 164  Ntsr1Cre_2020_0001  4   53        -/-      LGN       ON-sust.       NaN       NaN       NaN       NaN   -0.098346  False     excit
# 178  Ntsr1Cre_2020_0002  3   53        +/-      LGN            NaN       NaN       NaN       NaN       NaN   -3.310134   True     excit
# 182  Ntsr1Cre_2020_0002  4   23        +/-      LGN          mixed       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 188  Ntsr1Cre_2020_0002  4   55        +/-      LGN  ON-OFF-trans.       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 193  Ntsr1Cre_2020_0002  4   58        +/-      LGN       ON-sust.       NaN       NaN       NaN       NaN   -4.969315   True     excit
# 205  Ntsr1Cre_2020_0002  5   78        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 222  Ntsr1Cre_2020_0002  6   30        +/-      LGN            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 232  Ntsr1Cre_2020_0003  2   46        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 233  Ntsr1Cre_2020_0003  2   48        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 251  Ntsr1Cre_2020_0003  2   17        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 253  Ntsr1Cre_2020_0003  2    4        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 257  Ntsr1Cre_2020_0003  2  140        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 258  Ntsr1Cre_2020_0003  2  116        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN       NaN
# 259  Ntsr1Cre_2020_0003  2  101        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 260  Ntsr1Cre_2020_0003  2   67        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 261  Ntsr1Cre_2020_0003  2   11        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit
# 262  Ntsr1Cre_2020_0003  2   72        +/-       V1            NaN       NaN       NaN       NaN       NaN         NaN    NaN     excit

# %%
msudf.osi_ctrl.values
# Out:
# array([0.05834715, 0.01919398, 0.13226505, 0.122563  ,        nan,
#        0.03332981, 0.03547644, 0.20324785, 0.09005244, 0.10569687,
#        0.02745039, 0.02682709,        nan, 0.0131135 , 0.09205151,
#        0.05380423, 0.05867541, 0.07849464, 0.09851852,        nan,
#        0.05590137,        nan,        nan, 0.20295397, 0.13982949,
#        0.0704598 , 0.12935785, 0.08825168, 0.2244548 , 0.24449107,
#        0.15810173,        nan, 0.06202095,        nan, 0.09399421,
#               nan, 0.11933696,        nan, 0.10060412, 0.06970049,
#        0.0478129 , 0.02439646,        nan, 0.15857359, 0.24254185,
#        0.23513606, 0.12807236,        nan, 0.17054812, 0.03407635,
#        0.07786858, 0.09862634, 0.09209097, 0.07349512, 0.18423421,
#        0.09999673,        nan, 0.08633059, 0.03301052,        nan,
#               nan, 0.06543692, 0.05254197, 0.07164399, 0.10870015,
#        0.0797518 , 0.07062572, 0.05777392, 0.09999879, 0.02957786,
#        0.05132581, 0.03425497, 0.09946665, 0.06333901, 0.13425408,
#        0.11018807,        nan,        nan,        nan, 0.08508692,
#        0.02809382, 0.060064  , 0.2167764 , 0.09066039, 0.05477472,
#        0.14778621, 0.12200599, 0.0444796 , 0.05230264, 0.07127078,
#        0.12239598, 0.03164953, 0.12377183, 0.08304228, 0.13738524,
#               nan, 0.06489482, 0.10395952, 0.04018879,        nan,
#               nan,        nan,        nan, 0.05789166, 0.04918912,
#        0.15839972, 0.097294  ,        nan, 0.03260314, 0.3385534 ,
#        0.08345729, 0.14987066, 0.44517591, 0.07268771, 0.63356048,
#        0.05806809, 0.11978033,        nan, 0.214596  ,        nan,
#        0.13999991,        nan,        nan,        nan, 0.19414369,
#        0.14347882, 0.12244697, 0.04139049, 0.10569496, 0.2313948 ,
#        0.05367167, 0.2163676 , 0.02971172, 0.10010414, 0.10515053,
#        0.23137917, 0.0720266 , 0.01739736, 0.02929612, 0.19344814,
#        0.19887403, 0.21405754, 0.11205244, 0.023668  , 0.10321064,
#        0.06087235, 0.03720828,        nan, 0.11724029, 0.05486124,
#        0.0473503 , 0.3527579 , 0.1491382 , 0.18155159, 0.02149148,
#        0.01310104, 0.25250204, 0.1850664 , 0.06984022, 0.11805041,
#        0.07168286,        nan,        nan,        nan,        nan,
#        0.31746348, 0.07451139, 0.01633362, 0.10725388, 0.0623199 ,
#        0.18877082, 0.4072461 , 0.04688189, 0.07755432, 0.05445592,
#        0.14262309, 0.10458053, 0.0173992 ,        nan, 0.11515178,
#        0.13737405, 0.15832759,        nan, 0.0475635 , 0.07241454,
#        0.10872272, 0.03993624, 0.05192399,        nan, 0.03153241,
#        0.32759236, 0.26112136, 0.22214712,        nan, 0.11243514,
#        0.1393407 , 0.15769607, 0.11694724, 0.13372688, 0.0514839 ,
#        0.12278309, 0.04301358, 0.03552952, 0.05804625, 0.05331914,
#               nan, 0.03285791, 0.05255777, 0.12706909, 0.11133275,
#        0.34671797, 0.13976189, 0.06037519, 0.16382   , 0.08201097,
#        0.02750049, 0.14000675, 0.0617807 , 0.05690413, 0.05088219,
#        0.03558134, 0.05815908,        nan, 0.3313101 , 0.13235635,
#        0.31918586, 0.14754837, 0.33969034, 0.12344541, 0.1503796 ,
#        0.07934166, 0.04433495,        nan,        nan, 0.05782969,
#        0.13837526, 0.14335011, 0.19031728, 0.25089792, 0.37939047,
#        0.32436767, 0.40636666, 0.22908064, 0.0671087 , 0.1273807 ,
#        0.0532082 , 0.21729169, 0.07024278, 0.06450359, 0.10739276,
#        0.08713122,        nan, 1.01451076,        nan, 0.31551238,
#        0.61188325, 0.38708747,        nan,        nan,        nan,
#               nan,        nan,        nan])

# %% [markdown]
# ## Check validity of df vs DJD

# %%
df[df.e_name.str.contains('conTun_')][['m','s','u', 'e', 'sbc_zscore']]
# Out:
#                      m  s   u   e  sbc_zscore
# 72  Ntsr1Cre_2019_0002  3  13  10    4.203909
# 73  Ntsr1Cre_2019_0002  3  14  10    5.361450
# 74  Ntsr1Cre_2019_0002  3  19  10    1.382056
# 75  Ntsr1Cre_2019_0002  3  30  10    1.541808
# 76  Ntsr1Cre_2019_0002  3  40  10   -0.382231
# 77  Ntsr1Cre_2019_0002  3  45  10    1.350742
# 78  Ntsr1Cre_2019_0002  3  59  10    1.985799
# 79  Ntsr1Cre_2019_0002  3  72  10    0.288736

# %%
df[df.e_name.str.contains('conTun_')].index.values
# Out:
# array([72, 73, 74, 75, 76, 77, 78, 79])

# %%
df[(df.m=='Ntsr1Cre_2019_0002') & (df.s==3) & (df.e_name.str.contains('conTun'))][['m','s','u', 'e', 'e_name', 'sbc_zscore', 'sbc']]
# Out:
#                      m  s   u   e         e_name  sbc_zscore    sbc
# 24  Ntsr1Cre_2019_0002  3  13   4  conTun12_opto    8.678365  False
# 25  Ntsr1Cre_2019_0002  3  14   4  conTun12_opto    4.316509  False
# 26  Ntsr1Cre_2019_0002  3  19   4  conTun12_opto    0.068580  False
# 27  Ntsr1Cre_2019_0002  3  30   4  conTun12_opto    1.423739  False
# 28  Ntsr1Cre_2019_0002  3  40   4  conTun12_opto    2.780215  False
# 29  Ntsr1Cre_2019_0002  3  45   4  conTun12_opto   -1.805905  False
# 30  Ntsr1Cre_2019_0002  3  59   4  conTun12_opto    2.316554  False
# 31  Ntsr1Cre_2019_0002  3  72   4  conTun12_opto    1.080685  False
# 72  Ntsr1Cre_2019_0002  3  13  10    conTun_opto    4.203909  False
# 73  Ntsr1Cre_2019_0002  3  14  10    conTun_opto    5.361450  False
# 74  Ntsr1Cre_2019_0002  3  19  10    conTun_opto    1.382056  False
# 75  Ntsr1Cre_2019_0002  3  30  10    conTun_opto    1.541808  False
# 76  Ntsr1Cre_2019_0002  3  40  10    conTun_opto   -0.382231  False
# 77  Ntsr1Cre_2019_0002  3  45  10    conTun_opto    1.350742  False
# 78  Ntsr1Cre_2019_0002  3  59  10    conTun_opto    1.985799  False
# 79  Ntsr1Cre_2019_0002  3  72  10    conTun_opto    0.288736  False

# %%
## Check SbC zscores - which to use?

# %%
# df = df[df['sbc_zscore'].notna()][['m','s','u','e_name','sbc_zscore']]
df = df[df['sbc_zscore'].notna()][['e_name','sbc_zscore']]

df
# Out:
#              e_name  sbc_zscore
# 16    oriTun12_opto    3.288161
# 17    oriTun12_opto    7.661878
# 18    oriTun12_opto    4.236185
# 19    oriTun12_opto    5.810582
# 20    oriTun12_opto    6.814885
# ...             ...         ...
# 2364  conTun12_opto    0.876844
# 2365  conTun12_opto    0.153820
# 2366  conTun12_opto    0.074350
# 2367  conTun12_opto    3.841556
# 2368  conTun12_opto    1.131615
#
# [560 rows x 2 columns]

# %%
df.hist(by=df.e_name)
plt.tight_layout()
